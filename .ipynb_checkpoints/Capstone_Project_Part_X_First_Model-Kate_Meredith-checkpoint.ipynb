# %%
# rerun with test train split data

# %% [markdown]
# # Capstone Project Part 4: First Model Test
#
# **Authur:** Kate Meredith
#
# **Date:** September-November 2022
#
# **Notebook #**: 4 of
#
# ## Background
#
# **Source:** Data was collected from [CoffeeReview.com](https://www.coffeereview.com/) and grouped into two DataFrames for cleaning. See "Capstone Project Part 1" for more information on scraping. See notebook on cleaning "older_data_df" for cleaning of that portion of data.
#
# This first test uses the first portion of cleaned data based on "data-df".

# %%
#Importing libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
coffee = pd.read_csv('coffee.csv')

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6557 entries, 0 to 6556
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   coffee_name    6557 non-null   object
#  1   roaster_name   6557 non-null   object
#  2   month          6557 non-null   int64
#  3   year           6557 non-null   int64
#  4   bean_agtron    6557 non-null   int64
#  5   ground_agtron  6557 non-null   int64
#  6   aroma          6557 non-null   int64
#  7   acidity        6557 non-null   int64
#  8   body           6557 non-null   int64
#  9   flavor         6557 non-null   int64
#  10  aftertaste     6557 non-null   int64
#  11  roaster_lat    6557 non-null   float64
#  12  roaster_lon    6557 non-null   float64
#  13  origin_lat     6557 non-null   float64
#  14  origin_lon     6557 non-null   float64
#  15  p1             6557 non-null   object
#  16  p2             6557 non-null   object
# ...

# %%
#drop unneeded columns
clean_df.drop(['coffee_name', 'roaster_name', 'p1', 'p2', 'p3'], axis=1, inplace=True)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4779 entries, 0 to 4778
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   roast_level           4705 non-null   float64
#  1   overall_score         4779 non-null   int64
#  2   bean_agtron           4742 non-null   float64
#  3   ground_agtron         4743 non-null   float64
#  4   year                  4779 non-null   int64
#  5   month                 4779 non-null   int64
#  6   roaster_location_lat  4738 non-null   float64
#  7   roaster_location_lon  4738 non-null   float64
#  8   origin_lat            4513 non-null   float64
#  9   origin_lon            4513 non-null   float64
#  10  aroma                 4743 non-null   float64
#  11  acidity               4049 non-null   float64
#  12  body                  4779 non-null   int64
#  13  flavor                4779 non-null   int64
#  14  aftertaste            4779 non-null   int64
# ...

# %%
clean_df.isnull().sum()
# Out:
# roast_level              74
# overall_score             0
# bean_agtron              37
# ground_agtron            36
# year                      0
# month                     0
# roaster_location_lat     41
# roaster_location_lon     41
# origin_lat              266
# origin_lon              266
# aroma                    36
# acidity                 730
# body                      0
# flavor                    0
# aftertaste                0
# dtype: int64

# %%
#drop unneeded columns
clean_df.drop(['with_milk'], axis=1, inplace=True)

# %%
clean_df.dropna(inplace=True)

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3816 entries, 0 to 4778
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   roast_level           3816 non-null   float64
#  1   overall_score         3816 non-null   int64
#  2   bean_agtron           3816 non-null   float64
#  3   ground_agtron         3816 non-null   float64
#  4   year                  3816 non-null   int64
#  5   month                 3816 non-null   int64
#  6   roaster_location_lat  3816 non-null   float64
#  7   roaster_location_lon  3816 non-null   float64
#  8   origin_lat            3816 non-null   float64
#  9   origin_lon            3816 non-null   float64
#  10  aroma                 3816 non-null   float64
#  11  acidity               3816 non-null   float64
#  12  body                  3816 non-null   int64
#  13  flavor                3816 non-null   int64
#  14  aftertaste            3816 non-null   int64
# ...

# %%
X = clean_df.drop('overall_score', axis = 1)

# %%
X.head()
# Out:
#    roast_level  bean_agtron  ground_agtron  year  month  roaster_location_lat  \
# 0          2.0         60.0           77.0  2022     10             37.973535
# 1          2.0         58.0           78.0  2022     10             33.448437
# 2          2.0         59.0           77.0  2022     10             33.448437
# 3          2.0         62.0           78.0  2022     10             37.973535
# 4          1.0         65.0           81.0  2022     10             25.072134
#
#    roaster_location_lon  origin_lat  origin_lon  aroma  acidity  body  flavor  \
# 0           -122.531087    4.099917  -72.908813    9.0      9.0     9       9
# 1           -112.074141   -6.869970  -75.045851    9.0      9.0     9       9
# 2           -112.074141    4.099917  -72.908813    9.0      9.0     8       9
# 3           -122.531087   12.609016  -85.293691    8.0      8.0     9       9
# 4            121.679919   10.211670   38.652120    9.0      9.0     8       9
#
#    aftertaste
# ...

# %%
y = clean_df['overall_score']

# %%
y.shape
# Out:
# (3816,)

# %%
# 1. Instantiate the model
lr_model = LinearRegression()

# 2. Fit the model
lr_model.fit(X, y)
# Out:
# LinearRegression()

# %%
model_prediction = lr_model.predict(X)

# %%
from sklearn.metrics import r2_score

# %%
# Evaluate the model
print(f'The R2 score: {r2_score(y, model_prediction)}')
# Out:
# The R2 score: 0.9918650118723703

# %%
# 3. Scoring the model
lr_model.score(X, y)
# Out:
# 0.9918650118723703

# %%
corr_df = X.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr_df.round(2), vmax = 1, vmin = -1, center=0, cmap="coolwarm",annot=True)
plt.show()

# %%
corr_df2=clean_df.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr_df2.round(2), vmax = 1, vmin = -1, center=0, cmap="coolwarm",annot=True)
plt.show()
