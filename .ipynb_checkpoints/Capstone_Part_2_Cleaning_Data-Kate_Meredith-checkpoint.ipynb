# %% [markdown]
# # Capstone Project Part 2
#
# Authur: Kate Meredith
# Date: September 2022
#
# ## Data Cleaning
#
# Data is collected from [CoffeeReview.com](https://www.coffeereview.com/).

# %% [markdown]
# ## References
#
# - Referenced this [article](https://www.geeksforgeeks.org/split-a-text-column-into-two-columns-in-pandas-dataframe/) for splitting columns and keeping in dataframe
# - For [splitting columns with nans](https://stackoverflow.com/questions/69354795/how-to-skip-nan-values-when-splitting-up-a-column)
# - References for [cleaning up measurement columns](https://www.geeksforgeeks.org/how-to-replace-values-in-column-based-on-condition-in-pandas/)
# - Used [Regex 101](https://regex101.com/) to verify regex replacements
# - Used these articles to address turning datatypes to integers with nan present:
#     - [Changing to nans](https://stackoverflow.com/questions/34794067/how-to-set-a-cell-to-nan-in-a-pandas-dataframe)
#     - [Using numpy to allow nans in integers](https://stackoverflow.com/questions/21287624/convert-pandas-column-containing-nans-to-dtype-int)
# - Used this stack overflow [article](https://stackoverflow.com/questions/25888396/how-to-get-latitude-longitude-with-python) to acquire lat and long for locations

# %%
##########
#continue with column clean up, trying to reduce number of values for cost down to main ounces, grams, etc

# %%
#Importing libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import first dataset
data_df = pd.read_csv('data_df.csv')

# %%
data_df.shape
# Out:
# (4779, 22)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4779 entries, 0 to 4778
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   coffee_name       4779 non-null   object
#  1   roaster_name      4779 non-null   object
#  2   roaster_location  4779 non-null   object
#  3   coffee_origin     4779 non-null   object
#  4   roast_level       4705 non-null   object
#  5   agtron            4779 non-null   object
#  6   est_price         4731 non-null   object
#  7   review_date       4779 non-null   object
#  8   overall_score     4779 non-null   int64
#  9   h1                4779 non-null   object
#  10  s1                4779 non-null   int64
#  11  h2                4779 non-null   object
#  12  s2                4779 non-null   int64
#  13  h3                4779 non-null   object
#  14  s3                4779 non-null   int64
#  15  h4                4779 non-null   object
#  16  s4                4779 non-null   int64
#  17  h5                4779 non-null   object
#  18  s5                4779 non-null   int64
#  19  p1                4779 non-null   object
#  20  p2                4779 non-null   object
#  21  p3                4773 non-null   object
# dtypes: int64(6), object(16)
# memory usage: 821.5+ KB

# %%
data_df.head()
# Out:
#                              coffee_name     roaster_name  \
# 0              Colombia Cerro Azul Enano  Equator Coffees
# 1                         Peru Incahuasi     Press Coffee
# 2            Colombia Aponte’s Guardians     Press Coffee
# 3        Nicaragua Flor de Dalia Natural  Equator Coffees
# 4  Ethiopia Bench Maji Geisha G1 Natural  Taster's Coffee
#
#           roaster_location                                      coffee_origin  \
# 0   San Rafael, California     Trujillo, Valle del Cauca Department, Colombia
# 1         Phoenix, Arizona                                 Cusco Region, Peru
# 2         Phoenix, Arizona                        Nariño Department, Colombia
# 3   San Rafael, California  La Dalia, Matagalpa Department, northern Nicar...
# 4  New Taipei City, Taiwan                 Bench-Maji Zone, southern Ethiopia
#
#     roast_level agtron          est_price   review_date  overall_score  \
# 0  Medium-Light  60/77   $26.00/12 ounces  October 2022             94
# 1  Medium-Light  58/78   $26.00/12 ounces  October 2022             94
# 2  Medium-Light  59/77   $19.00/12 ounces  October 2022             93
# 3  Medium-Light  62/78   $18.00/12 ounces  October 2022             92
# 4         Light  65/81  NT $520/227 grams  October 2022             93
#
#        h1  ...  s2     h3  s3       h4  s4           h5  s5  \
# 0  Aroma:  ...   9  Body:   9  Flavor:   9  Aftertaste:   8
# 1  Aroma:  ...   9  Body:   9  Flavor:   9  Aftertaste:   8
# 2  Aroma:  ...   9  Body:   8  Flavor:   9  Aftertaste:   8
# 3  Aroma:  ...   8  Body:   9  Flavor:   9  Aftertaste:   8
# 4  Aroma:  ...   9  Body:   8  Flavor:   9  Aftertaste:   8
#
#                                                   p1  \
# 0  Blind Assessment: Elegantly fruit- and cocoa-t...
# 1  Blind Assessment: Gently fruit-toned, integrat...
# 2  Blind Assessment: Richly sweet, spice-toned. L...
# 3  Blind Assessment: Gently fruit-forward, sweetl...
# 4  Blind Assessment: Gently sweet-tart, floral-to...
#
#                                                   p2  \
# 0  Notes: Produced at Finca Cerro Azul (also owne...
# 1  Notes: Produced at Incahuasi Farm from trees o...
# 2  Notes: Produced at Aponte Farm from an undiscl...
# 3  Notes: Produced by smallholding members of the...
# 4  Notes: Produced from trees of the admired bota...
#
#                                                   p3
# 0  The Bottom Line:  This rare Enano (dwarf Geish...
# 1  The Bottom Line: Laden with tropical fruit not...
# 2  The Bottom Line: A balanced, inviting washed C...
# 3  The Bottom Line: A refreshing, very sweet natu...
# 4  The Bottom Line: A quietly confident natural-p...
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Checking Values in Each Column

# %%
#coffee name value counts
data_df['coffee_name'].value_counts()
# Out:
# Holiday Blend                                      21
# Espresso Blend                                     20
# Ethiopia Yirgacheffe                               11
# Sumatra Tano Batak                                  9
# Ethiopia Hambela Natural                            8
#                                                    ..
# Kenya Handege                                       1
# Kauai Estate Reserve Sun-Dried Typica               1
# Colombia Valle del Cauca Cerro Azul Geisha          1
# Ecuador Loja Clara Sidra Natural Taza Dorada #2     1
# Rwanda Coopac Cooperative                           1
# Name: coffee_name, Length: 4231, dtype: int64

# %%
#roaster name value counts
data_df['roaster_name'].value_counts()
# Out:
# JBC Coffee Roasters          291
# Paradise Roasters            230
# Kakalove Cafe                170
# Temple Coffee and Tea        103
# Bird Rock Coffee Roasters     92
#                             ...
# Boil Line Coffee Company       1
# Red Giant Coffee Roasters      1
# Pigeonhole Coffee              1
# Red E Café                     1
# Moonstruck Farm                1
# Name: roaster_name, Length: 870, dtype: int64

# %%
#roast location value counts
data_df['roaster_location'].value_counts()
# Out:
# Madison, Wisconsin        297
# Sacramento, California    201
# Chia-Yi, Taiwan           175
# San Diego, California     166
# Minneapolis, Minnesota    157
#                          ...
# San Juan, Puerto Rico       1
# Tempe Arizona               1
# Lexington, Kentucky         1
# St. Louis, MIssouri         1
# Pa'auilo, Hawaii            1
# Name: roaster_location, Length: 499, dtype: int64

# %%
#coffee origin value counts
data_df['coffee_origin'].value_counts()
# Out:
# Not disclosed.                                                           156
# Yirgacheffe growing region, southern Ethiopia                            147
# Yirgacheffe growing region, southern Ethiopia.                           109
# Boquete growing region, western Panama                                   100
# Nyeri growing region, south-central Kenya                                 99
#                                                                         ...
# La Libertad, Huehuetenango, Guatemala                                      1
# Cusco Department, La Convención Province, Santa Teresa District, Peru      1
# San Cristobal, Cobán, Alta Verapaz, Guatemala                              1
# Jamaica                                                                    1
# Nilgiris, southern India.                                                  1
# Name: coffee_origin, Length: 1794, dtype: int64

# %%
#roast level value counts
data_df['roast_level'].value_counts()
# Out:
# Medium-Light    2592
# Medium          1067
# Light            584
# Medium-Dark      299
# Very Dark        118
# Dark              45
# Name: roast_level, dtype: int64

# %%
#agtron value counts
data_df['agtron'].value_counts()
# Out:
# 58/76     133
# 58/78     114
# 60/78     108
# 62/80      84
# 56/78      81
#          ...
# 64/94       1
# 72/102      1
# 39/47       1
# 63/88       1
# 49/78       1
# Name: agtron, Length: 764, dtype: int64

# %%
#est_price value counts
data_df['est_price'].value_counts()
# Out:
# $18.00/12 ounces                          154
# $16.00/12 ounces                           95
# $20.00/12 ounces                           91
# $19.00/12 ounces                           87
# $15.00/12 ounces                           84
#                                          ...
# $9.99/7 ounces (198 grams)                  1
# $19.00/six 5-gram packets                   1
# $15.00/six 5-gram single-serve packets      1
# $22.00/eight 5-gram tubes                   1
# $14.25 / 12 oz.                             1
# Name: est_price, Length: 1537, dtype: int64

# %%
#review_date value counts
data_df['review_date'].value_counts()
# Out:
# November 2021    66
# March 2021       63
# August 2021      63
# October 2020     61
# August 2020      61
#                  ..
# January 2017      8
# December 2009     3
# October 2009      1
# August 2009       1
# June 2009         1
# Name: review_date, Length: 156, dtype: int64

# %%
#overall_score value counts
data_df['overall_score'].value_counts()
# Out:
# 93    1191
# 92     914
# 94     873
# 91     470
# 95     414
# 90     388
# 89     129
# 96     115
# 88     104
# 87      55
# 97      28
# 86      24
# 85      17
# 84      12
# 83       7
# 79       6
# 77       4
# 75       3
# 73       3
# 80       3
# 98       3
# 67       3
# 68       2
# 72       2
# 78       2
# 63       1
# 82       1
# 71       1
# 74       1
# 76       1
# 66       1
# 69       1
# Name: overall_score, dtype: int64

# %%
#h1 value counts
data_df['h1'].value_counts()
# Out:
# Aroma:                4743
# Acidity/Structure:      24
# Acidity:                12
# Name: h1, dtype: int64

# %%
#s1 value counts
data_df['s1'].value_counts()
# Out:
# 9     3207
# 8     1322
# 7      121
# 10      95
# 6       15
# 5        9
# 4        5
# 2        3
# 3        2
# Name: s1, dtype: int64

# %%
#h2 value counts
data_df['h2'].value_counts()
# Out:
# Acidity:              2078
# Acidity/Structure:    1935
# Body:                  766
# Name: h2, dtype: int64

# %%
#s2 value counts
data_df['s2'].value_counts()
# Out:
# 8     2437
# 9     1952
# 7      327
# 6       28
# 10      15
# 4        6
# 3        5
# 5        5
# 1        2
# 2        2
# Name: s2, dtype: int64

# %%
#h3 value counts
data_df['h3'].value_counts()
# Out:
# Body:      4013
# Flavor:     766
# Name: h3, dtype: int64

# %%
#s3 value counts
data_df['s3'].value_counts()
# Out:
# 9     2436
# 8     2165
# 7      143
# 6       18
# 10      15
# 5        2
# Name: s3, dtype: int64

# %%
#h4 value counts
data_df['h4'].value_counts()
# Out:
# Flavor:        4013
# Aftertaste:     766
# Name: h4, dtype: int64

# %%
#s4 value counts
data_df['s4'].value_counts()
# Out:
# 9     3278
# 8     1085
# 10     213
# 7      164
# 6       11
# 5        9
# 3        8
# 4        8
# 2        2
# 1        1
# Name: s4, dtype: int64

# %%
#h5 value counts
data_df['h5'].value_counts()
# Out:
# Aftertaste:    4013
# With Milk:      766
# Name: h5, dtype: int64

# %%
#s5 value counts
data_df['s5'].value_counts()
# Out:
# 8     2975
# 9     1220
# 7      494
# 10      31
# 6       29
# 5       12
# 4       10
# 3        6
# 2        2
# Name: s5, dtype: int64

# %% [markdown]
# ### Splitting agtron into two columns, one for whole bean score and one for ground score
#
# - The first number refers to the bean agtron score
# - The second number refers to the ground agtron score

# %%
#split agtron into 2 columns
data_df[['bean_agtron','ground_agtron']] = data_df['agtron'].str.split("/",expand=True)

# %%
#verify split
data_df
# Out:
#                                     coffee_name  \
# 0                     Colombia Cerro Azul Enano
# 1                                Peru Incahuasi
# 2                   Colombia Aponte’s Guardians
# 3               Nicaragua Flor de Dalia Natural
# 4         Ethiopia Bench Maji Geisha G1 Natural
# ...                                         ...
# 4774                               Kenya AA Top
# 4775  Ethiopia Washed Yirgacheffe, Koke Grade 1
# 4776                      India Balmaadi Estate
# 4777       Organic Bolivia CENAPROC Cooperative
# 4778                  Rwanda Coopac Cooperative
#
#                            roaster_name         roaster_location  \
# 0                       Equator Coffees   San Rafael, California
# 1                          Press Coffee         Phoenix, Arizona
# 2                          Press Coffee         Phoenix, Arizona
# 3                       Equator Coffees   San Rafael, California
# 4                       Taster's Coffee  New Taipei City, Taiwan
# ...                                 ...                      ...
# 4774  Simon Hsieh's Aroma Roast Coffees     Taoyuan City, Taiwan
# 4775  Simon Hsieh's Aroma Roast Coffees     Taoyuan City, Taiwan
# 4776              Tony's Coffees & Teas   Bellingham, Washington
# 4777                 Wonderstate Coffee       Viroqua, Wisconsin
# 4778                 Wonderstate Coffee       Viroqua, Wisconsin
#
#                                           coffee_origin   roast_level agtron  \
# 0        Trujillo, Valle del Cauca Department, Colombia  Medium-Light  60/77
# 1                                    Cusco Region, Peru  Medium-Light  58/78
# 2                           Nariño Department, Colombia  Medium-Light  59/77
# 3     La Dalia, Matagalpa Department, northern Nicar...  Medium-Light  62/78
# 4                    Bench-Maji Zone, southern Ethiopia         Light  65/81
# ...                                                 ...           ...    ...
# 4774                                              Kenya        Medium  49/64
# 4775  Yirgacheffe growing region, Sidamo Province, s...  Medium-Light  49/78
# 4776                          Nilgiris, southern India.  Medium-Light  57/72
# 4777                  Caranavi growing region, Bolivia.  Medium-Light  57/81
# 4778                                             Rwanda        Medium  53/68
#
#               est_price    review_date  overall_score      h1  ...  s3  \
# 0      $26.00/12 ounces   October 2022             94  Aroma:  ...   9
# 1      $26.00/12 ounces   October 2022             94  Aroma:  ...   9
# 2      $19.00/12 ounces   October 2022             93  Aroma:  ...   8
# 3      $18.00/12 ounces   October 2022             92  Aroma:  ...   9
# 4     NT $520/227 grams   October 2022             93  Aroma:  ...   8
# ...                 ...            ...            ...     ...  ...  ..
# 4774                NaN  December 2009             96  Aroma:  ...   8
# 4775                NaN  December 2009             97  Aroma:  ...   8
# 4776                NaN   October 2009             91  Aroma:  ...   8
# 4777                NaN    August 2009             90  Aroma:  ...   8
# 4778                NaN      June 2009             90  Aroma:  ...   8
#
#            h4  s4           h5  s5  \
# 0     Flavor:   9  Aftertaste:   8
# 1     Flavor:   9  Aftertaste:   8
# 2     Flavor:   9  Aftertaste:   8
# 3     Flavor:   9  Aftertaste:   8
# 4     Flavor:   9  Aftertaste:   8
# ...       ...  ..          ...  ..
# 4774  Flavor:  10  Aftertaste:   9
# 4775  Flavor:  10  Aftertaste:   9
# 4776  Flavor:   9  Aftertaste:   8
# 4777  Flavor:   8  Aftertaste:   8
# 4778  Flavor:   8  Aftertaste:   8
#
#                                                      p1  \
# 0     Blind Assessment: Elegantly fruit- and cocoa-t...
# 1     Blind Assessment: Gently fruit-toned, integrat...
# 2     Blind Assessment: Richly sweet, spice-toned. L...
# 3     Blind Assessment: Gently fruit-forward, sweetl...
# 4     Blind Assessment: Gently sweet-tart, floral-to...
# ...                                                 ...
# 4774  Blind Assessment: Deep and penetrating floral ...
# 4775  Blind Assessment: Startlingly intense, sweet-t...
# 4776  Blind Assessment: Sweet-toned, balanced, quiet...
# 4777  Blind Assessment: Nut, flowers and blackberryi...
# 4778  Blind Assessment: Balanced, pungent character ...
#
#                                                      p2  \
# 0     Notes: Produced at Finca Cerro Azul (also owne...
# 1     Notes: Produced at Incahuasi Farm from trees o...
# 2     Notes: Produced at Aponte Farm from an undiscl...
# 3     Notes: Produced by smallholding members of the...
# 4     Notes: Produced from trees of the admired bota...
# ...                                                 ...
# 4774  Notes: In addition to his retail roasting oper...
# 4775  Notes: Koke is a particularly high-elevation d...
# 4776  Notes: This coffee is certified organically gr...
# 4777  Notes: Despite high growing elevations Bolivia...
# 4778  Notes: Rwanda's tremendous potential as fine c...
#
#                                                      p3  bean_agtron  \
# 0     The Bottom Line:  This rare Enano (dwarf Geish...           60
# 1     The Bottom Line: Laden with tropical fruit not...           58
# 2     The Bottom Line: A balanced, inviting washed C...           59
# 3     The Bottom Line: A refreshing, very sweet natu...           62
# 4     The Bottom Line: A quietly confident natural-p...           65
# ...                                                 ...          ...
# 4774  Who Should Drink It: An exceptional example of...           49
# 4775  Who Should Drink It: The Yirgacheffe style at ...           49
# 4776  Who Should Drink It: Those who value subtlety ...           57
# 4777  Who Should Drink It: A deeply rounded and bala...           57
# 4778  Who Should Drink It: A simple, rich Rwanda wit...           53
#
#      ground_agtron
# 0               77
# 1               78
# 2               77
# 3               78
# 4               81
# ...            ...
# 4774            64
# 4775            78
# 4776            72
# 4777            81
# 4778            68
#
# [4779 rows x 24 columns]

# %%
#drop unneeded agtron column
data_df.drop('agtron', axis=1, inplace=True)

# %%
#checking drop
data_df.head()
# Out:
#                              coffee_name     roaster_name  \
# 0              Colombia Cerro Azul Enano  Equator Coffees
# 1                         Peru Incahuasi     Press Coffee
# 2            Colombia Aponte’s Guardians     Press Coffee
# 3        Nicaragua Flor de Dalia Natural  Equator Coffees
# 4  Ethiopia Bench Maji Geisha G1 Natural  Taster's Coffee
#
#           roaster_location                                      coffee_origin  \
# 0   San Rafael, California     Trujillo, Valle del Cauca Department, Colombia
# 1         Phoenix, Arizona                                 Cusco Region, Peru
# 2         Phoenix, Arizona                        Nariño Department, Colombia
# 3   San Rafael, California  La Dalia, Matagalpa Department, northern Nicar...
# 4  New Taipei City, Taiwan                 Bench-Maji Zone, southern Ethiopia
#
#     roast_level          est_price   review_date  overall_score      h1  s1  \
# 0  Medium-Light   $26.00/12 ounces  October 2022             94  Aroma:   9
# 1  Medium-Light   $26.00/12 ounces  October 2022             94  Aroma:   9
# 2  Medium-Light   $19.00/12 ounces  October 2022             93  Aroma:   9
# 3  Medium-Light   $18.00/12 ounces  October 2022             92  Aroma:   8
# 4         Light  NT $520/227 grams  October 2022             93  Aroma:   9
#
#    ... s3       h4 s4           h5 s5  \
# 0  ...  9  Flavor:  9  Aftertaste:  8
# 1  ...  9  Flavor:  9  Aftertaste:  8
# 2  ...  8  Flavor:  9  Aftertaste:  8
# 3  ...  9  Flavor:  9  Aftertaste:  8
# 4  ...  8  Flavor:  9  Aftertaste:  8
#
#                                                   p1  \
# 0  Blind Assessment: Elegantly fruit- and cocoa-t...
# 1  Blind Assessment: Gently fruit-toned, integrat...
# 2  Blind Assessment: Richly sweet, spice-toned. L...
# 3  Blind Assessment: Gently fruit-forward, sweetl...
# 4  Blind Assessment: Gently sweet-tart, floral-to...
#
#                                                   p2  \
# 0  Notes: Produced at Finca Cerro Azul (also owne...
# 1  Notes: Produced at Incahuasi Farm from trees o...
# 2  Notes: Produced at Aponte Farm from an undiscl...
# 3  Notes: Produced by smallholding members of the...
# 4  Notes: Produced from trees of the admired bota...
#
#                                                   p3 bean_agtron ground_agtron
# 0  The Bottom Line:  This rare Enano (dwarf Geish...          60            77
# 1  The Bottom Line: Laden with tropical fruit not...          58            78
# 2  The Bottom Line: A balanced, inviting washed C...          59            77
# 3  The Bottom Line: A refreshing, very sweet natu...          62            78
# 4  The Bottom Line: A quietly confident natural-p...          65            81
#
# [5 rows x 23 columns]

# %%
#checking data types for agtron scores
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4779 entries, 0 to 4778
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   coffee_name       4779 non-null   object
#  1   roaster_name      4779 non-null   object
#  2   roaster_location  4779 non-null   object
#  3   coffee_origin     4779 non-null   object
#  4   roast_level       4705 non-null   object
#  5   est_price         4731 non-null   object
#  6   review_date       4779 non-null   object
#  7   overall_score     4779 non-null   int64
#  8   h1                4779 non-null   object
#  9   s1                4779 non-null   int64
#  10  h2                4779 non-null   object
#  11  s2                4779 non-null   int64
#  12  h3                4779 non-null   object
#  13  s3                4779 non-null   int64
#  14  h4                4779 non-null   object
#  15  s4                4779 non-null   int64
#  16  h5                4779 non-null   object
#  17  s5                4779 non-null   int64
#  18  p1                4779 non-null   object
#  19  p2                4779 non-null   object
#  20  p3                4773 non-null   object
#  21  bean_agtron       4779 non-null   object
#  22  ground_agtron     4779 non-null   object
# dtypes: int64(6), object(17)
# memory usage: 858.9+ KB

# %% [markdown]
# ### Turning new agtron columns into numerical values

# %%
#checking values to see which need updated to allow switch to integer
data_df['bean_agtron'].unique()
# Out:
# array(['60', '58', '59', '62', '65', '46', '57', '56', '48', '64', '52',
#        '61', '54', '45', '76', '68', '51', '55', '63', '44', '47', '50',
#        '0', '75', '40', '38', '32', '34', '53', '49', '42', '66', '36',
#        '35', '39', '82', '74', '85', '79', '5252', '547', '555', '67',
#        '43', '41', '31', '69', 'NA', '37', '', '71', '70', '86', '78',
#        '72', '81', '73', '33', '21', '20', '25', '29', '27', '22'],
#       dtype=object)

# %%
#turning NA into nans
data_df['bean_agtron'].replace('NA', np.nan, inplace=True)

# %%
#turning blank into nans
data_df['bean_agtron'].replace('', np.nan, inplace=True)

# %%
#converting to integer
data_df['bean_agtron'] = data_df['bean_agtron'].astype('Int8')

# %%
#checking values to see which need updated to allow switch to integer
data_df['ground_agtron'].unique()
# Out:
# array(['77', '78', '81', '74', '82', '72', '67', '84', '86', '70', '80',
#        '79', '76', '69', '66', '85', '92', '71', '88', '87', '75', '60',
#        '61', '73', '0', '64', '62', '93', '58', '54', '50', '52', '56',
#        '53', '44', '68', '65', '57', '83', '48', '63', '59', '104', '94',
#        '105', '90', '96', '55', '46', '49', 'NA', '45', '', '91', '37',
#        '99', '97', '89', '38', '51', '47', '40', '95', '98', '29', '34',
#        '41', '43', '102', '39', '101', '42', '33', '36', '28', '30', '31',
#        '32', '26', '18'], dtype=object)

# %%
#turning NA into nans
data_df['ground_agtron'].replace('NA', np.nan, inplace=True)

# %%
#turning blank into nans
data_df['ground_agtron'].replace('', np.nan, inplace=True)

# %%
#converting to integer
data_df['ground_agtron'] = data_df['ground_agtron'].astype('Int8')

# %%
#verifying data type updates
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4779 entries, 0 to 4778
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   coffee_name       4779 non-null   object
#  1   roaster_name      4779 non-null   object
#  2   roaster_location  4779 non-null   object
#  3   coffee_origin     4779 non-null   object
#  4   roast_level       4705 non-null   object
#  5   review_date       4779 non-null   datetime64[ns]
#  6   overall_score     4779 non-null   int64
#  7   h1                4779 non-null   object
#  8   s1                4779 non-null   int64
#  9   h2                4779 non-null   object
#  10  s2                4779 non-null   int64
#  11  h3                4779 non-null   object
#  12  s3                4779 non-null   int64
#  13  h4                4779 non-null   object
#  14  s4                4779 non-null   int64
#  15  h5                4779 non-null   object
#  16  s5                4779 non-null   int64
#  17  p1                4779 non-null   object
#  18  p2                4779 non-null   object
#  19  p3                4773 non-null   object
#  20  bean_agtron       4742 non-null   Int8
#  21  ground_agtron     4743 non-null   Int8
#  22  est_price_amount  4664 non-null   object
#  23  est_price_vol     4719 non-null   object
#  24  est_price_meas    4779 non-null   object
#  25  currency          4731 non-null   object
#  26  year              4779 non-null   int64
#  27  month             4779 non-null   int64
# dtypes: Int8(2), datetime64[ns](1), int64(8), object(17)
# memory usage: 989.5+ KB

# %%
data_df.head()
# Out:
#                              coffee_name     roaster_name  \
# 0              Colombia Cerro Azul Enano  Equator Coffees
# 1                         Peru Incahuasi     Press Coffee
# 2            Colombia Aponte’s Guardians     Press Coffee
# 3        Nicaragua Flor de Dalia Natural  Equator Coffees
# 4  Ethiopia Bench Maji Geisha G1 Natural  Taster's Coffee
#
#           roaster_location                                      coffee_origin  \
# 0   San Rafael, California     Trujillo, Valle del Cauca Department, Colombia
# 1         Phoenix, Arizona                                 Cusco Region, Peru
# 2         Phoenix, Arizona                        Nariño Department, Colombia
# 3   San Rafael, California  La Dalia, Matagalpa Department, northern Nicar...
# 4  New Taipei City, Taiwan                 Bench-Maji Zone, southern Ethiopia
#
#     roast_level review_date  overall_score      h1  s1                  h2  \
# 0  Medium-Light  2022-10-01             94  Aroma:   9  Acidity/Structure:
# 1  Medium-Light  2022-10-01             94  Aroma:   9  Acidity/Structure:
# 2  Medium-Light  2022-10-01             93  Aroma:   9  Acidity/Structure:
# 3  Medium-Light  2022-10-01             92  Aroma:   8  Acidity/Structure:
# 4         Light  2022-10-01             93  Aroma:   9  Acidity/Structure:
#
#    ...                                                 p2  \
# 0  ...  Notes: Produced at Finca Cerro Azul (also owne...
# 1  ...  Notes: Produced at Incahuasi Farm from trees o...
# 2  ...  Notes: Produced at Aponte Farm from an undiscl...
# 3  ...  Notes: Produced by smallholding members of the...
# 4  ...  Notes: Produced from trees of the admired bota...
#
#                                                   p3  bean_agtron  \
# 0  The Bottom Line:  This rare Enano (dwarf Geish...           60
# 1  The Bottom Line: Laden with tropical fruit not...           58
# 2  The Bottom Line: A balanced, inviting washed C...           59
# 3  The Bottom Line: A refreshing, very sweet natu...           62
# 4  The Bottom Line: A quietly confident natural-p...           65
#
#   ground_agtron  est_price_amount est_price_vol  est_price_meas currency  \
# 0            77             26.00            12          ounces
# 1            78             26.00            12          ounces
# 2            77             19.00            12          ounces
# 3            78             18.00            12          ounces
# 4            81               520           227           grams      NT
#
#    year month
# 0  2022    10
# 1  2022    10
# 2  2022    10
# 3  2022    10
# 4  2022    10
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Splitting estimated price into usable columns
#
# Background - estimated price data uses a number of different measures. Breaking it apart with goal of converting to same measure so that they can be compared in a meaningful way.

# %%
#split  into 2 columns
data_df[['est_price_amount','est_price_measure']] = data_df['est_price'].str.split("/", n=1, expand=True)

# %%
#checking column split
data_df
# Out:
#                                     coffee_name  \
# 0                     Colombia Cerro Azul Enano
# 1                                Peru Incahuasi
# 2                   Colombia Aponte’s Guardians
# 3               Nicaragua Flor de Dalia Natural
# 4         Ethiopia Bench Maji Geisha G1 Natural
# ...                                         ...
# 4774                               Kenya AA Top
# 4775  Ethiopia Washed Yirgacheffe, Koke Grade 1
# 4776                      India Balmaadi Estate
# 4777       Organic Bolivia CENAPROC Cooperative
# 4778                  Rwanda Coopac Cooperative
#
# ...                                                 ...
# 4774  Notes: In addition to his retail roasting oper...
# 4775  Notes: Koke is a particularly high-elevation d...
# 4776  Notes: This coffee is certified organically gr...
# 4777  Notes: Despite high growing elevations Bolivia...
# 4778  Notes: Rwanda's tremendous potential as fine c...
#
#                                                      p3 bean_agtron  \
# 0     The Bottom Line:  This rare Enano (dwarf Geish...          60
# 1     The Bottom Line: Laden with tropical fruit not...          58
# 2     The Bottom Line: A balanced, inviting washed C...          59
# 3     The Bottom Line: A refreshing, very sweet natu...          62
# 4     The Bottom Line: A quietly confident natural-p...          65
# ...                                                 ...         ...
# 4774  Who Should Drink It: An exceptional example of...          49
# 4775  Who Should Drink It: The Yirgacheffe style at ...          49
# 4776  Who Should Drink It: Those who value subtlety ...          57
# 4777  Who Should Drink It: A deeply rounded and bala...          57
# 4778  Who Should Drink It: A simple, rich Rwanda wit...          53
#
#       ground_agtron est_price_amount est_price_measure
# 0                77           $26.00         12 ounces
# 1                78           $26.00         12 ounces
# 2                77           $19.00         12 ounces
# 3                78           $18.00         12 ounces
# 4                81          NT $520         227 grams
# ...             ...              ...               ...
# 4774             64              NaN               NaN
# 4775             78              NaN               NaN
# 4776             72              NaN               NaN
# 4777             81              NaN               NaN
# 4778             68              NaN               NaN
#
# [4779 rows x 25 columns]

# %%
#drop unneeded est_price column
data_df.drop('est_price', axis=1, inplace=True)
data_df
# Out:
#                                     coffee_name  \
# 0                     Colombia Cerro Azul Enano
# 1                                Peru Incahuasi
# 2                   Colombia Aponte’s Guardians
# 3               Nicaragua Flor de Dalia Natural
# 4         Ethiopia Bench Maji Geisha G1 Natural
# ...                                         ...
# 4774                               Kenya AA Top
# 4775  Ethiopia Washed Yirgacheffe, Koke Grade 1
# 4776                      India Balmaadi Estate
# 4777       Organic Bolivia CENAPROC Cooperative
# 4778                  Rwanda Coopac Cooperative
#
#                            roaster_name         roaster_location  \
# 0                       Equator Coffees   San Rafael, California
# 1                          Press Coffee         Phoenix, Arizona
# 2                          Press Coffee         Phoenix, Arizona
# 3                       Equator Coffees   San Rafael, California
# 4                       Taster's Coffee  New Taipei City, Taiwan
# ...                                 ...                      ...
# 4774  Simon Hsieh's Aroma Roast Coffees     Taoyuan City, Taiwan
# 4775  Simon Hsieh's Aroma Roast Coffees     Taoyuan City, Taiwan
# 4776              Tony's Coffees & Teas   Bellingham, Washington
# 4777                 Wonderstate Coffee       Viroqua, Wisconsin
# 4778                 Wonderstate Coffee       Viroqua, Wisconsin
#
#                                           coffee_origin   roast_level  \
# 0        Trujillo, Valle del Cauca Department, Colombia  Medium-Light
# 1                                    Cusco Region, Peru  Medium-Light
# 2                           Nariño Department, Colombia  Medium-Light
# 3     La Dalia, Matagalpa Department, northern Nicar...  Medium-Light
# 4                    Bench-Maji Zone, southern Ethiopia         Light
# ...                                                 ...           ...
# 4774                                              Kenya        Medium
# 4775  Yirgacheffe growing region, Sidamo Province, s...  Medium-Light
# 4776                          Nilgiris, southern India.  Medium-Light
# 4774            64              NaN               NaN
# 4775            78              NaN               NaN
# 4776            72              NaN               NaN
# 4777            81              NaN               NaN
# 4778            68              NaN               NaN
#
# [4779 rows x 24 columns]

# %%
#split  into 2 columns
data_df[['est_price_vol','est_price_meas']] = data_df['est_price_measure'].str.split(" ", n=1, expand=True)

# %%
data_df
# Out:
#                                     coffee_name  \
# 0                     Colombia Cerro Azul Enano
# 1                                Peru Incahuasi
# 2                   Colombia Aponte’s Guardians
# 3               Nicaragua Flor de Dalia Natural
# 4         Ethiopia Bench Maji Geisha G1 Natural
# ...                                         ...
# 4774                               Kenya AA Top
# 4775  Ethiopia Washed Yirgacheffe, Koke Grade 1
# 4776                      India Balmaadi Estate
# 4777       Organic Bolivia CENAPROC Cooperative
# 4778                  Rwanda Coopac Cooperative
#
#                            roaster_name         roaster_location  \
# 0                       Equator Coffees   San Rafael, California
# 1                          Press Coffee         Phoenix, Arizona
# 2                          Press Coffee         Phoenix, Arizona
# 3                       Equator Coffees   San Rafael, California
# 4                       Taster's Coffee  New Taipei City, Taiwan
# ...                                 ...                      ...
# 4774  Simon Hsieh's Aroma Roast Coffees     Taoyuan City, Taiwan
# 4775  Simon Hsieh's Aroma Roast Coffees     Taoyuan City, Taiwan
# 4776              Tony's Coffees & Teas   Bellingham, Washington
# 4777                 Wonderstate Coffee       Viroqua, Wisconsin
# 4778                 Wonderstate Coffee       Viroqua, Wisconsin
#
#                                           coffee_origin   roast_level  \
# 0        Trujillo, Valle del Cauca Department, Colombia  Medium-Light
# 1                                    Cusco Region, Peru  Medium-Light
# 2                           Nariño Department, Colombia  Medium-Light
# 3     La Dalia, Matagalpa Department, northern Nicar...  Medium-Light
# 4                    Bench-Maji Zone, southern Ethiopia         Light
# ...                                                 ...           ...
# 4774                                              Kenya        Medium
# 4775  Yirgacheffe growing region, Sidamo Province, s...  Medium-Light
# 4776                          Nilgiris, southern India.  Medium-Light
# 4777                  Caranavi growing region, Bolivia.  Medium-Light
# 4778                                             Rwanda        Medium
#
#         review_date  overall_score      h1  s1                  h2  ...  s5  \
# 0      October 2022             94  Aroma:   9  Acidity/Structure:  ...   8
# 1      October 2022             94  Aroma:   9  Acidity/Structure:  ...   8
# 2      October 2022             93  Aroma:   9  Acidity/Structure:  ...   8
# 3      October 2022             92  Aroma:   8  Acidity/Structure:  ...   8
# 4      October 2022             93  Aroma:   9  Acidity/Structure:  ...   8
# ...             ...            ...     ...  ..                 ...  ...  ..
# 4774  December 2009             96  Aroma:   9            Acidity:  ...   9
# 4775  December 2009             97  Aroma:   9            Acidity:  ...   9
# 4776   October 2009             91  Aroma:   8            Acidity:  ...   8
# 4777    August 2009             90  Aroma:   7            Acidity:  ...   8
# 4778      June 2009             90  Aroma:   8            Acidity:  ...   8
#
#                                                      p1  \
# 0     Blind Assessment: Elegantly fruit- and cocoa-t...
# 1     Blind Assessment: Gently fruit-toned, integrat...
# 2     Blind Assessment: Richly sweet, spice-toned. L...
# 3     Blind Assessment: Gently fruit-forward, sweetl...
# 4     Blind Assessment: Gently sweet-tart, floral-to...
# ...                                                 ...
# 4774  Blind Assessment: Deep and penetrating floral ...
# 4775  Blind Assessment: Startlingly intense, sweet-t...
# 4776  Blind Assessment: Sweet-toned, balanced, quiet...
# 4777  Blind Assessment: Nut, flowers and blackberryi...
# 4778  Blind Assessment: Balanced, pungent character ...
#
#                                                      p2  \
# 0     Notes: Produced at Finca Cerro Azul (also owne...
# 1     Notes: Produced at Incahuasi Farm from trees o...
# 2     Notes: Produced at Aponte Farm from an undiscl...
# 3     Notes: Produced by smallholding members of the...
# 4     Notes: Produced from trees of the admired bota...
# ...                                                 ...
# 4774  Notes: In addition to his retail roasting oper...
# 4775  Notes: Koke is a particularly high-elevation d...
# 4776  Notes: This coffee is certified organically gr...
# 4777  Notes: Despite high growing elevations Bolivia...
# 4778  Notes: Rwanda's tremendous potential as fine c...
#
#                                                      p3  bean_agtron  \
# 0     The Bottom Line:  This rare Enano (dwarf Geish...           60
# 1     The Bottom Line: Laden with tropical fruit not...           58
# 2     The Bottom Line: A balanced, inviting washed C...           59
# 3     The Bottom Line: A refreshing, very sweet natu...           62
# 4     The Bottom Line: A quietly confident natural-p...           65
# ...                                                 ...          ...
# 4774  Who Should Drink It: An exceptional example of...           49
# 4775  Who Should Drink It: The Yirgacheffe style at ...           49
# 4776  Who Should Drink It: Those who value subtlety ...           57
# 4777  Who Should Drink It: A deeply rounded and bala...           57
# 4778  Who Should Drink It: A simple, rich Rwanda wit...           53
#
#      ground_agtron  est_price_amount est_price_measure est_price_vol  \
# 0               77            $26.00         12 ounces            12
# 1               78            $26.00         12 ounces            12
# 2               77            $19.00         12 ounces            12
# 3               78            $18.00         12 ounces            12
# 4               81           NT $520         227 grams           227
# ...            ...               ...               ...           ...
# 4774            64               NaN               NaN           NaN
# 4775            78               NaN               NaN           NaN
# 4776            72               NaN               NaN           NaN
# 4777            81               NaN               NaN           NaN
# 4778            68               NaN               NaN           NaN
#
#      est_price_meas
# 0            ounces
# 1            ounces
# 2            ounces
# 3            ounces
# 4             grams
# ...             ...
# 4774            NaN
# 4775            NaN
# 4776            NaN
# 4777            NaN
# 4778            NaN
#
# [4779 rows x 26 columns]

# %%
#drop unneeded est_price column
data_df.drop('est_price_measure', axis=1, inplace=True)
data_df
# Out:
#                                     coffee_name  \
# 0                     Colombia Cerro Azul Enano
# 1                                Peru Incahuasi
# 2                   Colombia Aponte’s Guardians
# 3               Nicaragua Flor de Dalia Natural
# 4         Ethiopia Bench Maji Geisha G1 Natural
# ...                                         ...
# 4774                               Kenya AA Top
# 4775  Ethiopia Washed Yirgacheffe, Koke Grade 1
# 4776                      India Balmaadi Estate
# 4777       Organic Bolivia CENAPROC Cooperative
# 4778                  Rwanda Coopac Cooperative
#
#                            roaster_name         roaster_location  \
# 0                       Equator Coffees   San Rafael, California
# 1                          Press Coffee         Phoenix, Arizona
# 2                          Press Coffee         Phoenix, Arizona
# 3                       Equator Coffees   San Rafael, California
# 4                       Taster's Coffee  New Taipei City, Taiwan
#
#                                                      p3 bean_agtron  \
# 0     The Bottom Line:  This rare Enano (dwarf Geish...          60
# 1     The Bottom Line: Laden with tropical fruit not...          58
# 2     The Bottom Line: A balanced, inviting washed C...          59
# 3     The Bottom Line: A refreshing, very sweet natu...          62
# 4     The Bottom Line: A quietly confident natural-p...          65
# ...                                                 ...         ...
# 4774  Who Should Drink It: An exceptional example of...          49
# 4775  Who Should Drink It: The Yirgacheffe style at ...          49
# 4776  Who Should Drink It: Those who value subtlety ...          57
# 4777  Who Should Drink It: A deeply rounded and bala...          57
# 4778  Who Should Drink It: A simple, rich Rwanda wit...          53
#
#       ground_agtron est_price_amount est_price_vol est_price_meas
# 0                77           $26.00            12         ounces
# 1                78           $26.00            12         ounces
# 2                77           $19.00            12         ounces
# 3                78           $18.00            12         ounces
# 4                81          NT $520           227          grams
# ...             ...              ...           ...            ...
# 4774             64              NaN           NaN            NaN
# 4775             78              NaN           NaN            NaN
# 4776             72              NaN           NaN            NaN
# 4777             81              NaN           NaN            NaN
# 4778             68              NaN           NaN            NaN
#
# [4779 rows x 25 columns]

# %%
data_df['est_price_meas'].value_counts()
# Out:
# ounces                                    3703
# grams                                      534
# oz.                                        148
# K-Cups                                      42
# capsules                                    29
#                                           ...
# ounces (2 types)                             1
# ounces (sold out)                            1
# ounces (currently on sale for $36.76)        1
# ounces online; $12.99/ounces in stores       1
# 10 oz.                                       1
# Name: est_price_meas, Length: 106, dtype: int64

# %%
data_df
# Out:
#                                     coffee_name  \
# 0                     Colombia Cerro Azul Enano
# 1                                Peru Incahuasi
# 2                   Colombia Aponte’s Guardians
# 3               Nicaragua Flor de Dalia Natural
# 4         Ethiopia Bench Maji Geisha G1 Natural
# ...                                         ...
# 4774                               Kenya AA Top
# 4775  Ethiopia Washed Yirgacheffe, Koke Grade 1
# 4776                      India Balmaadi Estate
# 4777       Organic Bolivia CENAPROC Cooperative
# 4778                  Rwanda Coopac Cooperative
#
#                            roaster_name         roaster_location  \
# 0                       Equator Coffees   San Rafael, California
# 1                          Press Coffee         Phoenix, Arizona
# 2                          Press Coffee         Phoenix, Arizona
# 3                       Equator Coffees   San Rafael, California
# 4                       Taster's Coffee  New Taipei City, Taiwan
# ...                                 ...                      ...
# 4774  Simon Hsieh's Aroma Roast Coffees     Taoyuan City, Taiwan
# 4775  Simon Hsieh's Aroma Roast Coffees     Taoyuan City, Taiwan
# 4776              Tony's Coffees & Teas   Bellingham, Washington
# 4777                 Wonderstate Coffee       Viroqua, Wisconsin
# 4778                 Wonderstate Coffee       Viroqua, Wisconsin
#
#                                           coffee_origin   roast_level  \
# 0        Trujillo, Valle del Cauca Department, Colombia  Medium-Light
# 1                                    Cusco Region, Peru  Medium-Light
# 2                           Nariño Department, Colombia  Medium-Light
# 3     La Dalia, Matagalpa Department, northern Nicar...  Medium-Light
# 4                    Bench-Maji Zone, southern Ethiopia         Light
# ...                                                 ...           ...
# 4774                                              Kenya        Medium
# 4775  Yirgacheffe growing region, Sidamo Province, s...  Medium-Light
# 4776                          Nilgiris, southern India.  Medium-Light
# 4777                  Caranavi growing region, Bolivia.  Medium-Light
# 4778                                             Rwanda        Medium
#
#         review_date  overall_score      h1  s1                  h2  ...  \
# 0      October 2022             94  Aroma:   9  Acidity/Structure:  ...
# 1      October 2022             94  Aroma:   9  Acidity/Structure:  ...
# 2      October 2022             93  Aroma:   9  Acidity/Structure:  ...
# 3      October 2022             92  Aroma:   8  Acidity/Structure:  ...
# 4      October 2022             93  Aroma:   9  Acidity/Structure:  ...
# ...             ...            ...     ...  ..                 ...  ...
# 4774  December 2009             96  Aroma:   9            Acidity:  ...
# 4775  December 2009             97  Aroma:   9            Acidity:  ...
# 4776   October 2009             91  Aroma:   8            Acidity:  ...
# 4777    August 2009             90  Aroma:   7            Acidity:  ...
# 4778      June 2009             90  Aroma:   8            Acidity:  ...
#
#                h5 s5                                                 p1  \
# 0     Aftertaste:  8  Blind Assessment: Elegantly fruit- and cocoa-t...
# 1     Aftertaste:  8  Blind Assessment: Gently fruit-toned, integrat...
# 2     Aftertaste:  8  Blind Assessment: Richly sweet, spice-toned. L...
# 3     Aftertaste:  8  Blind Assessment: Gently fruit-forward, sweetl...
# 4     Aftertaste:  8  Blind Assessment: Gently sweet-tart, floral-to...
# ...           ... ..                                                ...
# 4774  Aftertaste:  9  Blind Assessment: Deep and penetrating floral ...
# 4775  Aftertaste:  9  Blind Assessment: Startlingly intense, sweet-t...
# 4776  Aftertaste:  8  Blind Assessment: Sweet-toned, balanced, quiet...
# 4777  Aftertaste:  8  Blind Assessment: Nut, flowers and blackberryi...
# 4778  Aftertaste:  8  Blind Assessment: Balanced, pungent character ...
#
#                                                      p2  \
# 0     Notes: Produced at Finca Cerro Azul (also owne...
# 1     Notes: Produced at Incahuasi Farm from trees o...
# 2     Notes: Produced at Aponte Farm from an undiscl...
# 3     Notes: Produced by smallholding members of the...
# 4     Notes: Produced from trees of the admired bota...
# ...                                                 ...
# 4774  Notes: In addition to his retail roasting oper...
# 4775  Notes: Koke is a particularly high-elevation d...
# 4776  Notes: This coffee is certified organically gr...
# 4777  Notes: Despite high growing elevations Bolivia...
# 4778  Notes: Rwanda's tremendous potential as fine c...
#
#                                                      p3 bean_agtron  \
# 0     The Bottom Line:  This rare Enano (dwarf Geish...          60
# 1     The Bottom Line: Laden with tropical fruit not...          58
# 2     The Bottom Line: A balanced, inviting washed C...          59
# 3     The Bottom Line: A refreshing, very sweet natu...          62
# 4     The Bottom Line: A quietly confident natural-p...          65
# ...                                                 ...         ...
# 4774  Who Should Drink It: An exceptional example of...          49
# 4775  Who Should Drink It: The Yirgacheffe style at ...          49
# 4776  Who Should Drink It: Those who value subtlety ...          57
# 4777  Who Should Drink It: A deeply rounded and bala...          57
# 4778  Who Should Drink It: A simple, rich Rwanda wit...          53
#
#       ground_agtron est_price_amount est_price_vol est_price_meas
# 0                77           $26.00            12         ounces
# 1                78           $26.00            12         ounces
# 2                77           $19.00            12         ounces
# 3                78           $18.00            12         ounces
# 4                81          NT $520           227          grams
# ...             ...              ...           ...            ...
# 4774             64              NaN           NaN            NaN
# 4775             78              NaN           NaN            NaN
# 4776             72              NaN           NaN            NaN
# 4777             81              NaN           NaN            NaN
# 4778             68              NaN           NaN            NaN
#
# [4779 rows x 25 columns]

# %% [markdown]
# Cleaning up value options to reduce number of categories in `est_price_meas`.

# %%
data_df['est_price_meas'].replace(r'.*(ounc).*', 'ounces', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(gram).*', 'grams', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(bottle).*', 'bottle', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(capsul).*', 'capsules', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(cups).*', 'K-Cups', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(ods).*', 'K-Cups', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(onc).*', 'K-Cups', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(Vue).*', 'K-Cups', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(oz).*', 'ounces', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(can).*', 'can', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(single-serve).*', 'capsules', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'.*(pound).*', 'pounds', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(g\.)', 'grams', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(g$)', 'grams', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(250.*)', 'grams', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(packet)', 'capsules', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(sticks)', 'capsules', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(kgrams.*)', 'kg', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(ml. flask)', 'bottle', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(tin)', 'unknown', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'((plus one donated))', 'capsules', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(.*apsul.*)', 'capsules', inplace = True, regex=True)

# %%
data_df['est_price_meas'].replace(r'(T Discs)', 'K-Cups', inplace = True, regex=True)

# %%
data_df['est_price_meas'].unique()
# Out:
# array(['ounces', 'grams', 'capsules', None, nan, 'bottle', 'can',
#        'unknown', 'pounds', 'K-Cups', 'kg'], dtype=object)

# %%
data_df['est_price_meas'].isnull().sum()
# Out:
# 76

# %%
data_df['est_price_meas'].fillna('unknown', inplace=True)

# %%
data_df['est_price_meas'].value_counts()
# Out:
# ounces      3968
# grams        589
# unknown       77
# K-Cups        67
# capsules      47
# bottle        14
# can            7
# pounds         6
# kg             4
# Name: est_price_meas, dtype: int64

# %%
data_df.head()
# Out:
#                              coffee_name     roaster_name  \
# 0              Colombia Cerro Azul Enano  Equator Coffees
# 1                         Peru Incahuasi     Press Coffee
# 2            Colombia Aponte’s Guardians     Press Coffee
# 3        Nicaragua Flor de Dalia Natural  Equator Coffees
# 4  Ethiopia Bench Maji Geisha G1 Natural  Taster's Coffee
#
#           roaster_location                                      coffee_origin  \
# 0   San Rafael, California     Trujillo, Valle del Cauca Department, Colombia
# 1         Phoenix, Arizona                                 Cusco Region, Peru
# 2         Phoenix, Arizona                        Nariño Department, Colombia
# 3   San Rafael, California  La Dalia, Matagalpa Department, northern Nicar...
# 4  New Taipei City, Taiwan                 Bench-Maji Zone, southern Ethiopia
#
#     roast_level   review_date  overall_score      h1  s1                  h2  \
# 0  Medium-Light  October 2022             94  Aroma:   9  Acidity/Structure:
# 1  Medium-Light  October 2022             94  Aroma:   9  Acidity/Structure:
# 2  Medium-Light  October 2022             93  Aroma:   9  Acidity/Structure:
# 3  Medium-Light  October 2022             92  Aroma:   8  Acidity/Structure:
# 4         Light  October 2022             93  Aroma:   9  Acidity/Structure:
#
#    ...           h5 s5                                                 p1  \
# 0  ...  Aftertaste:  8  Blind Assessment: Elegantly fruit- and cocoa-t...
# 1  ...  Aftertaste:  8  Blind Assessment: Gently fruit-toned, integrat...
# 2  ...  Aftertaste:  8  Blind Assessment: Richly sweet, spice-toned. L...
# 3  ...  Aftertaste:  8  Blind Assessment: Gently fruit-forward, sweetl...
# 4  ...  Aftertaste:  8  Blind Assessment: Gently sweet-tart, floral-to...
#
#                                                   p2  \
# 0  Notes: Produced at Finca Cerro Azul (also owne...
# 1  Notes: Produced at Incahuasi Farm from trees o...
# 2  Notes: Produced at Aponte Farm from an undiscl...
# 3  Notes: Produced by smallholding members of the...
# 4  Notes: Produced from trees of the admired bota...
#
#                                                   p3 bean_agtron  \
# 0  The Bottom Line:  This rare Enano (dwarf Geish...          60
# 1  The Bottom Line: Laden with tropical fruit not...          58
# 2  The Bottom Line: A balanced, inviting washed C...          59
# 3  The Bottom Line: A refreshing, very sweet natu...          62
# 4  The Bottom Line: A quietly confident natural-p...          65
#
#    ground_agtron est_price_amount est_price_vol est_price_meas
# 0             77           $26.00            12         ounces
# 1             78           $26.00            12         ounces
# 2             77           $19.00            12         ounces
# 3             78           $18.00            12         ounces
# 4             81          NT $520           227          grams
#
# [5 rows x 25 columns]

# %%
data_df['est_price_amount'].value_counts()
# Out:
# $18.00      191
# $20.00      132
# $15.00      127
# $16.00      119
# $19.00      107
#            ...
# RMB $105      1
# $27.75        1
# $23.10        1
# $47.50        1
# $14.25        1
# Name: est_price_amount, Length: 796, dtype: int64

# %%
#split agtron into 2 columns
data_df[['currency','est_price_amount']] = data_df['est_price_amount'].str.split("$", n=1, expand=True)

# %%
data_df.head()
# Out:
#                              coffee_name     roaster_name  \
# 0              Colombia Cerro Azul Enano  Equator Coffees
# 1                         Peru Incahuasi     Press Coffee
# 2            Colombia Aponte’s Guardians     Press Coffee
# 3        Nicaragua Flor de Dalia Natural  Equator Coffees
# 4  Ethiopia Bench Maji Geisha G1 Natural  Taster's Coffee
#
#           roaster_location                                      coffee_origin  \
# 0   San Rafael, California     Trujillo, Valle del Cauca Department, Colombia
# 1         Phoenix, Arizona                                 Cusco Region, Peru
# 2         Phoenix, Arizona                        Nariño Department, Colombia
# 3   San Rafael, California  La Dalia, Matagalpa Department, northern Nicar...
# 4  New Taipei City, Taiwan                 Bench-Maji Zone, southern Ethiopia
#
#     roast_level   review_date  overall_score      h1  s1                  h2  \
# 0  Medium-Light  October 2022             94  Aroma:   9  Acidity/Structure:
# 1  Medium-Light  October 2022             94  Aroma:   9  Acidity/Structure:
# 2  Medium-Light  October 2022             93  Aroma:   9  Acidity/Structure:
# 3  Medium-Light  October 2022             92  Aroma:   8  Acidity/Structure:
# 4         Light  October 2022             93  Aroma:   9  Acidity/Structure:
#
#    ...  s5                                                 p1  \
# 0  ...   8  Blind Assessment: Elegantly fruit- and cocoa-t...
# 1  ...   8  Blind Assessment: Gently fruit-toned, integrat...
# 2  ...   8  Blind Assessment: Richly sweet, spice-toned. L...
# 3  ...   8  Blind Assessment: Gently fruit-forward, sweetl...
# 4  ...   8  Blind Assessment: Gently sweet-tart, floral-to...
#
#                                                   p2  \
# 0  Notes: Produced at Finca Cerro Azul (also owne...
# 1  Notes: Produced at Incahuasi Farm from trees o...
# 2  Notes: Produced at Aponte Farm from an undiscl...
# 3  Notes: Produced by smallholding members of the...
# 4  Notes: Produced from trees of the admired bota...
#
#                                                   p3  bean_agtron  \
# 0  The Bottom Line:  This rare Enano (dwarf Geish...           60
# 1  The Bottom Line: Laden with tropical fruit not...           58
# 2  The Bottom Line: A balanced, inviting washed C...           59
# 3  The Bottom Line: A refreshing, very sweet natu...           62
# 4  The Bottom Line: A quietly confident natural-p...           65
#
#   ground_agtron  est_price_amount est_price_vol est_price_meas currency
# 0            77             26.00            12         ounces
# 1            78             26.00            12         ounces
# 2            77             19.00            12         ounces
# 3            78             18.00            12         ounces
# 4            81               520           227          grams      NT
#
# [5 rows x 26 columns]

# %%
data_df['currency'].value_counts()
# Out:
#               3715
# NT             640
# CAD            125
# NTD             43
# NT              24
#               ...
# NT 400           1
# KRW 19,000       1
# CNY              1
# €59.00           1
# THB 120          1
# Name: currency, Length: 71, dtype: int64

# %%
data_df['currency'].unique()
# Out:
# array(['', 'NT ', 'RM 130', 'RM 120', '£50', 'HKD ', 'NT',
#        'NA (available in store only)', '£100', nan, '¥1680', '¥88', '¥78',
#        '£25.00', '¥2980', '¥1,050', '500 pesos', '¥1280', 'CAD ',
#        '¥ 1,580', '¥ 2,640', '¥ 2,420', 'USD ', '£45', 'US ', 'HK ',
#        '£50.00', '€29.95', 'IDR ', 'AUD ',
#        'See website for more information', 'AED ', 'NTD ', '£40.50',
#        '9.9 Euros', '18.00', '#23.00', 'KRW ', 'NT 400', 'THB ',
#        'KRW 19,000', 'RMB ', 'CNY ', '€59.00', 'KRW 40,000', 'KRW 32,000',
#        'See review note', 'TWD ', 'NTD', 'RMB 235', 'KRW', 'KRW 50,000',
#        'KRW 95,000', '£5.50', '£7.00', '£6.50', '£5.00', '£6.50 for 250g',
#        '£7.45', 'KRW 35,000', 'KRW 15,000', 'E 50.00', 'KRW 10,000',
#        'GTQ 100', 'E 11.90', 'Not disclosed.', 'Not Available',
#        'Not available.', 'Price: ', 'THB 150', 'THB 450', 'THB 120'],
#       dtype=object)

# %% [markdown]
# Number of currencies and options is very complex, setting aside cost related columns for now.
#
# ### Turning `review_date` into datetime type and extracting month and year.
#
# For now, leaving `review_date` as a column, anticipate may drop later to reduce redundancy depending on which version will be used.

# %%
data_df['review_date'] = pd.to_datetime(data_df['review_date'])

# %%
data_df['year'] = pd.DatetimeIndex(data_df['review_date']).year

# %%
data_df['month'] = pd.DatetimeIndex(data_df['review_date']).month

# %%
data_df.head()
# Out:
#                              coffee_name     roaster_name  \
# 0              Colombia Cerro Azul Enano  Equator Coffees
# 1                         Peru Incahuasi     Press Coffee
# 2            Colombia Aponte’s Guardians     Press Coffee
# 3        Nicaragua Flor de Dalia Natural  Equator Coffees
# 4  Ethiopia Bench Maji Geisha G1 Natural  Taster's Coffee
#
#           roaster_location                                      coffee_origin  \
# 0   San Rafael, California     Trujillo, Valle del Cauca Department, Colombia
# 1         Phoenix, Arizona                                 Cusco Region, Peru
# 2         Phoenix, Arizona                        Nariño Department, Colombia
# 3   San Rafael, California  La Dalia, Matagalpa Department, northern Nicar...
# 4  New Taipei City, Taiwan                 Bench-Maji Zone, southern Ethiopia
#
#     roast_level review_date  overall_score      h1  s1                  h2  \
# 0  Medium-Light  2022-10-01             94  Aroma:   9  Acidity/Structure:
# 1  Medium-Light  2022-10-01             94  Aroma:   9  Acidity/Structure:
# 2  Medium-Light  2022-10-01             93  Aroma:   9  Acidity/Structure:
# 3  Medium-Light  2022-10-01             92  Aroma:   8  Acidity/Structure:
# 4         Light  2022-10-01             93  Aroma:   9  Acidity/Structure:
#
#    ...                                                 p2  \
# 0  ...  Notes: Produced at Finca Cerro Azul (also owne...
# 1  ...  Notes: Produced at Incahuasi Farm from trees o...
# 2  ...  Notes: Produced at Aponte Farm from an undiscl...
# 3  ...  Notes: Produced by smallholding members of the...
# 4  ...  Notes: Produced from trees of the admired bota...
#
#                                                   p3  bean_agtron  \
# 0  The Bottom Line:  This rare Enano (dwarf Geish...           60
# 1  The Bottom Line: Laden with tropical fruit not...           58
# 2  The Bottom Line: A balanced, inviting washed C...           59
# 3  The Bottom Line: A refreshing, very sweet natu...           62
# 4  The Bottom Line: A quietly confident natural-p...           65
#
#   ground_agtron  est_price_amount est_price_vol  est_price_meas currency  \
# 0            77             26.00            12          ounces
# 1            78             26.00            12          ounces
# 2            77             19.00            12          ounces
# 3            78             18.00            12          ounces
# 4            81               520           227           grams      NT
#
#    year month
# 0  2022    10
# 1  2022    10
# 2  2022    10
# 3  2022    10
# 4  2022    10
#
# [5 rows x 28 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4779 entries, 0 to 4778
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   coffee_name       4779 non-null   object
#  1   roaster_name      4779 non-null   object
#  2   roaster_location  4779 non-null   object
#  3   coffee_origin     4779 non-null   object
#  4   roast_level       4705 non-null   object
#  5   review_date       4779 non-null   datetime64[ns]
#  6   overall_score     4779 non-null   int64
#  7   h1                4779 non-null   object
#  8   s1                4779 non-null   int64
#  9   h2                4779 non-null   object
#  10  s2                4779 non-null   int64
#  11  h3                4779 non-null   object
#  12  s3                4779 non-null   int64
#  13  h4                4779 non-null   object
#  14  s4                4779 non-null   int64
#  15  h5                4779 non-null   object
#  16  s5                4779 non-null   int64
#  17  p1                4779 non-null   object
#  18  p2                4779 non-null   object
#  19  p3                4773 non-null   object
#  20  bean_agtron       4742 non-null   Int8
#  21  ground_agtron     4779 non-null   object
#  22  est_price_amount  4664 non-null   object
#  23  est_price_vol     4719 non-null   object
#  24  est_price_meas    4779 non-null   object
#  25  currency          4731 non-null   object
#  26  year              4779 non-null   int64
#  27  month             4779 non-null   int64
# dtypes: Int8(1), datetime64[ns](1), int64(8), object(18)
# memory usage: 1017.5+ KB

# %% [markdown]
# ### Turn locations into latitude and longitude

# %%
import requests
import urllib.parse

address = 'Phoenix, Arizona'
url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'

response = requests.get(url).json()
print(response)
print
# Out:
# [{'place_id': 297980425, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 111257, 'boundingbox': ['33.2903739', '33.9183794', '-112.3240289', '-111.9255304'], 'lat': '33.4484367', 'lon': '-112.074141', 'display_name': 'Phoenix, Maricopa County, Arizona, United States', 'class': 'boundary', 'type': 'administrative', 'importance': 0.8530162254733777, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'}, {'place_id': 225495583, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 570040210, 'boundingbox': ['33.8315399', '33.8366345', '-112.1704208', '-112.1664697'], 'lat': '33.8341051', 'lon': '-112.16843733164893', 'display_name': 'Federal Correctional Institution, Phoenix, 37900, Perimeter Road, Phoenix, Maricopa County, Arizona, 85086, United States', 'class': 'amenity', 'type': 'prison', 'importance': 0.5403958451676494, 'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/amenity_prison.p.20.png'}, {'place_id': 279523710, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 932542869, 'boundingbox': ['33.4606291', '33.4615095', '-112.077765', '-112.075155'], 'lat': '33.461066599999995', 'lon': '-112.07656365942579', 'display_name': 'Japanese Friendship Garden, West Latham Street, Phoenix, Maricopa County, Arizona, 85003, United States', 'class': 'leisure', 'type': 'garden', 'importance': 0.4635246308816305}, {'place_id': 207269536, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 455881903, 'boundingbox': ['32.7395368', '32.7420519', '-114.4827167', '-114.4801257'], 'lat': '32.7414365', 'lon': '-114.4817698', 'display_name': 'Phoenix, Buckshot, Yuma County, Arizona, United States', 'class': 'highway', 'type': 'service', 'importance': 0.295}]

# %%
import requests
import urllib.parse

address = 'Shivaji Nagar, Bangalore, KA 560001'
url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'

response = requests.get(url).json()
print(response[0]["lat"])
print(response[0]["lon"])
# Out:
# 12.9801559
# 77.6023714

# %%
address_list = data_df['roaster_location'].to_numpy()
address_list
# Out:
# 2683    Ethiopia Yirgacheffe Kebele Kochore  The WestBean Coffee Roasers
# 941   Colombia Java El Edén Limited Edition                Brioso Coffee
# 970                   Peru El Corazon Gesha           Wonderstate Coffee
#
#             roaster_location                                   coffee_origin  \
# 2089          Miami, Florida                                 Kenya; Ethiopia
# 360         Taichung, Taiwan           Colombia; Guatemala; Brazil; Ethiopia
# 460    San Diego, California                         Kirinyaga County, Kenya
# 732          Chia-Yi, Taiwan                      Nyaruguru District, Rwanda
# 3572  Bedford, New Hampshire        Karimikui growing region, central Kenya.
# 1586   Branford, Connecticut  Santa Ana Department, northwestern El Salvador
# 2933   San Diego, California            Thika growing region, central Kenya.
# 2683   San Diego, California   Yirgacheffe growing region, southern Ethiopia
# 941           Columbus, Ohio                                Tolima, Colombia
# 970       Viroqua, Wisconsin                Chirinos, Cajamarca Region, Peru
#
#        roast_level review_date  overall_score      h1  s1                  h2  \
# 2089  Medium-Light  2018-02-01             93  Aroma:   9  Acidity/Structure:
# 360         Medium  2022-02-01             93  Aroma:   9               Body:
# 460   Medium-Light  2021-11-01             94  Aroma:   9  Acidity/Structure:
# 732   Medium-Light  2021-06-01             93  Aroma:   9  Acidity/Structure:
# 3572        Medium  2013-09-01             95  Aroma:  10            Acidity:
# 1586  Medium-Light  2019-08-01             92  Aroma:   8  Acidity/Structure:
# 2933  Medium-Light  2015-09-01             93  Aroma:   8            Acidity:
# 2683  Medium-Light  2016-04-01             94  Aroma:   9            Acidity:
# 941   Medium-Light  2021-02-01             94  Aroma:   9  Acidity/Structure:
# 970   Medium-Light  2021-01-01             93  Aroma:   9  Acidity/Structure:
#
#       ...  bean_agtron ground_agtron  est_price_amount est_price_vol  \
# 2089  ...           53            77             22.00            12
# 360   ...           47            65               350           200
# 460   ...           58            76             16.50           250
# 732   ...           58            78               220             8
# 3572  ...           52            66             14.50            12
# 1586  ...           55            80             34.99            16
# 2933  ...           55            69             15.00             8
# 2683  ...           48            78             28.00            16
# 941   ...           58            80             30.00            12
# 970   ...           59            77             20.00             6
#
#       est_price_meas currency  year month roaster_location_lat  \
# 2089          ounces           2018     2           25.7741728
# 360            grams      NT   2022     2            24.163162
# 460            grams           2021    11           32.7174202
# 732           ounces      NT   2021     6           23.4871369
# 3572          ounces           2013     9           42.9464737
# 1586          ounces           2019     8           41.2795414
# 2933          ounces           2015     9           32.7174202
# 2683          ounces           2016     4           32.7174202
# 941           ounces           2021     2           39.9622601
# 970           ounces           2021     1           43.5569174
#
#      roaster_location_lon
# 2089            -80.19362
# 360           120.6478282
# 460          -117.1627728
# 732    120.40200825216095
# 3572          -71.5159015
# 1586          -72.8150989
# 2933         -117.1627728
# 2683         -117.1627728
# 941           -83.0007065
# 970           -90.8887413
#
# [10 rows x 30 columns]

# %%
##########
# To Do

# - see if locations can be changed to lat and lon
# - sort out headers and scores
# - text tokenizing for paragraphs
# - text tokenizing for names???
# - resolve est price/volume/currency columns
# - address second set of data

#options - can sequel make any of this easier? - finish in excel if needed?


###########
