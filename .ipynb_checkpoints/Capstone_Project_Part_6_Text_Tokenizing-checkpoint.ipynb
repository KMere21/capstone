# %% [markdown]
# # Capstone Project Part 6: Text Tokenizing
#
# **Authur:** Kate Meredith
#
# **Date:** September-November 2022
#
# **Notebook #**: 6 of
#
# ## Background
#
# **Source:** Data was collected from [CoffeeReview.com](https://www.coffeereview.com/). See prior notebooks for details on scraping, cleaning and compilation. This notebook focuses on tokenizing the review text.

# %%
#Importing libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### References
#
# - Used this [article](https://stackoverflow.com/questions/37080612/pandas-dataframe-filter-regex) for searching for specific text in columns

# %% [markdown]
# ### Importing and previewing data

# %%
coffee = pd.read_csv('coffee.csv')

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6557 entries, 0 to 6556
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   coffee_name    6557 non-null   object
#  1   roaster_name   6557 non-null   object
#  2   month          6557 non-null   int64
#  3   year           6557 non-null   int64
#  4   bean_agtron    6557 non-null   int64
#  5   ground_agtron  6557 non-null   int64
#  6   aroma          6557 non-null   int64
#  7   acidity        6557 non-null   int64
#  8   body           6557 non-null   int64
#  9   flavor         6557 non-null   int64
#  10  aftertaste     6557 non-null   int64
#  11  roaster_lat    6557 non-null   float64
#  12  roaster_lon    6557 non-null   float64
#  13  origin_lat     6557 non-null   float64
#  14  origin_lon     6557 non-null   float64
#  15  p1             6557 non-null   object
#  16  p2             6557 non-null   object
#  17  p3             6557 non-null   object
#  18  overall_score  6557 non-null   int64
# dtypes: float64(4), int64(10), object(5)
# memory usage: 973.4+ KB

# %%
coffee.shape
# Out:
# (6557, 19)

# %%
coffee.describe()
# Out:
#              month         year  bean_agtron  ground_agtron        aroma  \
# count  6557.000000  6557.000000  6557.000000    6557.000000  6557.000000
# mean      6.642062  2013.102181    52.229983      67.668598     8.360988
# std       3.437202     6.719059     8.411739      12.936090     0.927393
# min       1.000000  1997.000000    11.000000      12.000000     2.000000
# 25%       4.000000  2008.000000    48.000000      60.000000     8.000000
# 50%       7.000000  2014.000000    54.000000      71.000000     9.000000
# 75%      10.000000  2019.000000    58.000000      77.000000     9.000000
# max      12.000000  2022.000000    91.000000      99.000000    10.000000
#
#            acidity         body       flavor   aftertaste  roaster_lat  \
# count  6557.000000  6557.000000  6557.000000  6557.000000  6557.000000
# mean      7.904224     8.086472     8.361598     7.795638    37.027419
# std       1.023060     0.871203     1.065692     0.874365     9.504209
# min       1.000000     4.000000     1.000000     2.000000   -37.824425
# 25%       8.000000     8.000000     8.000000     7.000000    32.840162
# 50%       8.000000     8.000000     9.000000     8.000000    39.049011
# 75%       9.000000     9.000000     9.000000     8.000000    43.074761
# max      10.000000    10.000000    10.000000    10.000000    64.837845
#
#        roaster_lon   origin_lat   origin_lon  overall_score
# count  6557.000000  6557.000000  6557.000000    6557.000000
# mean    -64.412448    10.198811   -12.161417      90.873723
# std      81.708964    12.709097    68.848718       4.089739
# min    -159.582761   -30.292848  -155.428370      60.000000
# 25%    -117.423510     1.441968   -79.366697      90.000000
# 50%     -89.383761    10.211670     7.540121      92.000000
# 75%     -72.815099    13.800038    38.652120      93.000000
# max     152.952215    52.380033   153.125616      98.000000

# %% [markdown]
# ### Preprocessing
#
# Before we create our X and y, there are some repeated text words that appear in `p1`, `p2`, and `p3`. In most reviews, these paragrapsh correspond to:
#
# - p1: Blind Assessment
# - p2: Notes
# - p3: The Bottom Line OR Who Should Drink it
#
# We'll first check to see if these paragraphs do contain the information we expect.
#
# Checking the composition of paragraphs:

# %%
#see how many of p1 paragraphs reference which type of information
len(coffee.loc[coffee['p1'].str.contains(r'(Blind Assessment).*')])
# Out:
# /var/folders/jm/x73vvhpx2cd14qw0zx2ccfsc0000gn/T/ipykernel_4871/1218255241.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   len(coffee.loc[coffee['p1'].str.contains(r'(Blind Assessment).*')])
# 6557

# %%
#see how many of p2 paragraphs reference which type of information
len(coffee.loc[coffee['p2'].str.contains(r'(Notes).*')])
# Out:
# /var/folders/jm/x73vvhpx2cd14qw0zx2ccfsc0000gn/T/ipykernel_4871/3921903414.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   len(coffee.loc[coffee['p2'].str.contains(r'(Notes).*')])
# 6557

# %%
#see how many of p3 paragraphs reference which type of information
len(coffee.loc[coffee['p3'].str.contains(r'(The Bottom).*')])
# Out:
# /var/folders/jm/x73vvhpx2cd14qw0zx2ccfsc0000gn/T/ipykernel_4871/984657743.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   len(coffee.loc[coffee['p3'].str.contains(r'(The Bottom).*')])
# 2728

# %%
#see how many of p3 paragraphs reference which type of information
len(coffee.loc[coffee['p3'].str.contains(r'(Who Should).*')])
# Out:
# /var/folders/jm/x73vvhpx2cd14qw0zx2ccfsc0000gn/T/ipykernel_4871/2101417195.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   len(coffee.loc[coffee['p3'].str.contains(r'(Who Should).*')])
# 3777

# %% [markdown]
# As expected, paragraphs 1 and 2 contain consistent data, paragraph 3 is split. We'll need to remove "Blind Assessment", "The Bottom Line", "Who Should Drink it" and "Notes" from our bag of words as they appear in every review.
#
# Getting rid of repeat words:

# %%
#splitting out review scores
coffee[['ba','p1']] = coffee['p1'].str.split(":", n=1, expand=True)

# %%
#splitting out review scores
coffee[['N','p2']] = coffee['p2'].str.split(":", n=1, expand=True)

# %%
#splitting out review scores
coffee[['tbl','p3']] = coffee['p3'].str.split(":", n=1, expand=True)

# %%
#drop unneeded holding columns
coffee.drop(['ba', 'N', 'tbl'], axis=1, inplace=True)

# %%
#checking for nan
coffee.isna().sum()
# Out:
# coffee_name      0
# roaster_name     0
# month            0
# year             0
# bean_agtron      0
# ground_agtron    0
# aroma            0
# acidity          0
# body             0
# flavor           0
# aftertaste       0
# roaster_lat      0
# roaster_lon      0
# origin_lat       0
# origin_lon       0
# p1               0
# p2               0
# p3               3
# overall_score    0
# dtype: int64

# %%
#drop rows missing value in overall_score column 
coffee.dropna(subset = ['p3'], inplace=True)

# %%
len(coffee)
# Out:
# 6554

# %% [markdown]
# ### Creating X and y
#
# target = `overall_score`

# %%
X = coffee.drop('overall_score', axis = 1)

# %%
X.shape
# Out:
# (6554, 18)

# %%
y = coffee['overall_score']

# %%
y.shape
# Out:
# (6554,)

# %%
y.describe()
# Out:
# count    6554.000000
# mean       90.872902
# std         4.090446
# min        60.000000
# 25%        90.000000
# 50%        92.000000
# 75%        93.000000
# max        98.000000
# Name: overall_score, dtype: float64

# %%
#plot y distribution
plt.figure()
plt.hist(coffee['overall_score'])
plt.title('historgram of overall_score')
plt.show()

# %%
#create train/test split, using 20% given dataset size

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#create train/validate split, using 20% given dataset size

X_remain, X_val, y_remain, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
X_train.shape
# Out:
# (5243, 18)

# %%
X_remain.shape
# Out:
# (4194, 18)

# %%
X_val.shape
# Out:
# (1049, 18)

# %%
X_test.shape
# Out:
# (1311, 18)

# %% [markdown]
# Do my train, val, test splits have similar distributions?

# %%
#plot y val distribution
plt.figure()
plt.hist(y_remain)
plt.title('historgram of overall_score')
plt.show()

# %%
#plot y val distribution
plt.figure()
plt.hist(y_val)
plt.title('historgram of overall_score')
plt.show()

# %% [markdown]
# The test group looks a bit different but each group does have the range of values with somewhat similar distributions.

# %%
#plot y val distribution
plt.figure()
plt.hist(y_test)
plt.title('historgram of overall_score')
plt.show()

# %% [markdown]
# `p1` Creating the first bag of words as baseline.

# %%
# 1. Instantiate 
bagofwords_p1 = CountVectorizer(stop_words='english', min_df=5)

# 2. Fit 
bagofwords_p1.fit(X_remain["p1"])

# 3. Transform
p1_remain_transform = bagofwords.transform(X_remain["p1"])
p1_val_transform = bagofwords.transform(X_val["p1"])
p1_test_transform = bagofwords.transform(X_test["p1"])

# %% [markdown]
# Looking at the most popular words:

# %%
#the following looks at the 20 most popular words from paragraph 1

word_counts = pd.DataFrame(
    {"counts": p1_remain_transform.toarray().sum(axis=0)},
    index=bagofwords.get_feature_names()
).sort_values("counts", ascending=False)

word_counts.head(20).plot(kind="bar", figsize=(15, 5), legend=False)
plt.title("Top 20 most frequently occurring words")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/katemondal/opt/anaconda3/envs/capstone/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
bagofwords_p1.get_feature_names()
# Out:
# /Users/katemondal/opt/anaconda3/envs/capstone/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['100',
#  '25',
#  '250',
#  '25ml',
#  '81',
#  '82',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '89',
#  '90',
#  '91',
#  '92',
#  '93',
#  '94',
#  '95',
#  'accessible',
#  'according',
#  'acid',
#  'acidity',
#  'acidy',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'admired',
#  'african',
#  'aftertaste',
#  'agave',
#  'aged',
#  'aggressive',
#  'aggressively',
#  'agreeable',
#  'agreeably',
#  'agreed',
#  'akin',
#  'alive',
#  'allowing',
#  'allspice',
#  'almond',
#  'almondy',
#  'alyssum',
#  'amber',
#  'ambivalence',
#  'american',
#  'amplified',
#  'amplifies',
#  'anchored',
#  'andy',
#  'animate',
#  'animated',
#  'animates',
#  'anise',
#  'antigua',
#  'apparently',
#  'appealing',
#  'apple',
#  'apricot',
#  'aroma',
#  'aromas',
#  'aromatic',
#  'aromatically',
#  'aromatics',
#  'array',
#  'assertive',
#  'assessment',
#  'associated',
#  'astringency',
#  'astringent',
#  'attention',
#  'attracted',
#  'attractive',
#  'authoritative',
#  'authority',
#  'b60',
#  'b70',
#  'background',
#  'backgrounded',
#  'baggy',
#  'baked',
#  'baker',
#  'bakers',
#  'baking',
#  'balance',
#  'balanced',
#  'balances',
#  'balancing',
#  'balm',
#  'banana',
#  'bananaish',
#  'bar',
#  'barely',
#  'barest',
#  'bark',
#  'barley',
#  'barrel',
#  'base',
#  'based',
#  'bay',
#  'bean',
#  'beans',
#  'beautifully',
#  'bergamot',
#  'berries',
#  'berry',
#  'berryish',
#  'best',
#  'better',
#  'big',
#  'bing',
#  'bit',
#  'bite',
#  'bitter',
#  'bitterish',
#  'bitterness',
#  'bittersweet',
#  'bittersweetness',
#  'black',
#  'blackberry',
#  'blackcurrant',
#  'blend',
#  'blood',
#  'bloom',
#  'bloomed',
#  'blooming',
#  'blooms',
#  'blossom',
#  'blossoms',
#  'blue',
#  'blueberry',
#  'bodied',
#  'body',
#  'bold',
#  'bolger',
#  'boot',
#  'bottled',
#  'bouquet',
#  'bourbon',
#  'bracing',
#  'bracingly',
#  'brandied',
#  'brandy',
#  'brandyish',
#  'brazil',
#  'break',
#  'brewed',
#  'brewer',
#  'brewing',
#  'bright',
#  'brightening',
#  'brightly',
#  'brightness',
#  'brisk',
#  'briskly',
#  'brittle',
#  'broad',
#  'brown',
#  'buoyant',
#  'buoyantly',
#  'burned',
#  'butter',
#  'butterscotch',
#  'buttery',
#  'byron',
#  'cabernet',
#  'cacao',
#  'cacoa',
#  'called',
#  'calls',
#  'came',
#  'candied',
#  'candy',
#  'candycap',
#  'candyish',
#  'cane',
#  'cantaloupe',
#  'cap',
#  'cappuccino',
#  'capsule',
#  'caramel',
#  'caramelized',
#  'caramelly',
#  'carbon',
#  'carbony',
#  'cardamom',
#  'carnal',
#  'carnation',
#  'carob',
#  'carried',
#  'carries',
#  'carry',
#  'carrying',
#  'case',
#  'cashew',
#  'caused',
#  'cedar',
#  'cedarish',
#  'cedary',
#  'center',
#  'centered',
#  'centers',
#  'central',
#  'character',
#  'characteristic',
#  'characteristics',
#  'characterized',
#  'charred',
#  'cheese',
#  'cherries',
#  'cherry',
#  'cherryish',
#  'chewy',
#  'chocolate',
#  'chocolaty',
#  'chris',
#  'christy',
#  'cider',
#  'cidery',
#  'cinnamon',
#  'cited',
#  'citrus',
#  'citrusy',
#  'clarity',
#  'classic',
#  'classically',
#  'clay',
#  'clean',
#  'cleanly',
#  'clear',
#  'clearly',
#  'close',
#  'clove',
#  'clover',
#  'cloying',
#  'cloyingly',
#  'cocoa',
#  'cocoaish',
#  'coconut',
#  'coffee',
#  'coffees',
#  'cognac',
#  'cold',
#  'colombia',
#  'combination',
#  'combines',
#  'combining',
#  'come',
#  'comes',
#  'comfortable',
#  'coming',
#  'comments',
#  'compatible',
#  'compelling',
#  'complained',
#  'complemented',
#  'complete',
#  'completely',
#  'completeness',
#  'complex',
#  'complexity',
#  'complexly',
#  'complicate',
#  'complicated',
#  'complicates',
#  'complicating',
#  'complication',
#  'complications',
#  'component',
#  'composed',
#  'composty',
#  'concentrated',
#  'concluded',
#  'concord',
#  'confident',
#  'consensus',
#  'considerable',
#  'considerably',
#  'consistent',
#  'consolidate',
#  'consolidates',
#  'consolidating',
#  'containing',
#  'continued',
#  'continues',
#  'continuing',
#  'contribute',
#  'contributes',
#  'contributing',
#  'conventional',
#  'cooled',
#  'cools',
#  'cordial',
#  'coriander',
#  'coulis',
#  'covered',
#  'cracker',
#  'cranberry',
#  'cream',
#  'creamy',
#  'crisp',
#  'crisply',
#  'crispness',
#  'cumin',
#  'cup',
#  'cupped',
#  'cupper',
#  'cuppers',
#  'cupping',
#  'cups',
#  'curd',
#  'currant',
#  'cut',
#  'danny',
#  'dark',
#  'darker',
#  'darkish',
#  'date',
#  'decent',
#  'decisively',
#  'deep',
#  'deepen',
#  'deepened',
#  'deepening',
#  'deepens',
#  'deeper',
#  'deeply',
#  'defect',
#  'defects',
#  'definitely',
#  'delicacy',
#  'delicate',
#  'delicately',
#  'demitasse',
#  'dense',
#  'depending',
#  'depth',
#  'described',
#  'describes',
#  'description',
#  'descriptors',
#  'despite',
#  'dessert',
#  'detected',
#  'develop',
#  'developed',
#  'developing',
#  'development',
#  'develops',
#  'device',
#  'did',
#  'didn',
#  'difference',
#  'different',
#  'dimension',
#  'dimensioned',
#  'disappointing',
#  'discreet',
#  'discreetly',
#  'displayed',
#  'displaying',
#  'displays',
#  'distant',
#  'distinct',
#  'distinctive',
#  'distinctly',
#  'distracting',
#  'does',
#  'doesn',
#  'dominant',
#  'dominate',
#  'dominated',
#  'dominates',
#  'dominating',
#  'don',
#  'dramatic',
#  'dried',
#  'dries',
#  'drink',
#  'drinkers',
#  'driven',
#  'drop',
#  'dry',
#  'drying',
#  'dryly',
#  'dull',
#  'dusk',
#  'dynamic',
#  'earth',
#  'earthiness',
#  'earthy',
#  'east',
#  'easy',
#  'echoes',
#  'edge',
#  'edged',
#  'edges',
#  'edging',
#  'effervescent',
#  'elegance',
#  'elegant',
#  'elegantly',
#  'elevated',
#  'elm',
#  'emerge',
#  'emerged',
#  'emerges',
#  'end',
#  'engaging',
#  'engagingly',
#  'enjoyed',
#  'enlivened',
#  'enthusiasm',
#  'entire',
#  'entirely',
#  'enveloped',
#  'enveloping',
#  'equal',
#  'ese',
#  'especially',
#  'espresso',
#  'essential',
#  'ethan',
#  'eucalyptus',
#  'evaluated',
#  'example',
#  'excellent',
#  'exceptional',
#  'exceptionally',
#  'exciting',
#  'exhilarating',
#  'exhilaratingly',
#  'exotic',
#  'expansive',
#  'explicit',
#  'express',
#  'expressed',
#  'expression',
#  'expressive',
#  'exquisite',
#  'exquisitely',
#  'extends',
#  'extraordinarily',
#  'extraordinary',
#  'extravagant',
#  'extravagantly',
#  'extremely',
#  'fade',
#  'faded',
#  'fades',
#  'fading',
#  'faint',
#  'faintly',
#  'fallen',
#  'familiar',
#  'far',
#  'fat',
#  'fattens',
#  'fault',
#  'favorite',
#  'felt',
#  'fennel',
#  'ferment',
#  'fermented',
#  'fermenty',
#  'fig',
#  'fills',
#  'finally',
#  'finding',
#  'finds',
#  'fine',
#  'finely',
#  'finish',
#  'finishes',
#  'finishing',
#  'fir',
#  'flat',
#  'flatness',
#  'flattens',
#  'flavor',
#  'flavored',
#  'flavors',
#  'floral',
#  'florals',
#  'flower',
#  'flowering',
#  'flowers',
#  'focused',
#  'followed',
#  'footed',
#  'forceful',
#  'foregrounds',
#  'forest',
#  'foresty',
#  'format',
#  'forward',
#  'fragrance',
#  'fragrant',
#  'framed',
#  'francisfrancis',
#  'frankincense',
#  'free',
#  'freesia',
#  'fresh',
#  'freshly',
#  'fruit',
#  'fruitiness',
#  'fruity',
#  'fudge',
#  'fudgy',
#  'fullish',
#  'fully',
#  'functional',
#  'fundamental',
#  'fundamentally',
#  'gardenia',
#  'gave',
#  'general',
#  'generally',
#  'gentle',
#  'gently',
#  'giddily',
#  'giddy',
#  'ginger',
#  'gingery',
#  'ginseng',
#  'given',
#  'gives',
#  'goat',
#  'going',
#  'goji',
#  'golden',
#  'good',
#  'grace',
#  'graceful',
#  'gracefully',
#  'graham',
#  'grain',
#  'grams',
#  'grandly',
#  'grape',
#  'grapefruit',
#  'grapefruity',
#  'grapey',
#  'grappa',
#  'grapy',
#  'grass',
#  'grassy',
#  'great',
#  'green',
#  'gritty',
#  'ground',
#  'grounded',
#  'grow',
#  'grown',
#  'grows',
#  'guatemala',
#  'guava',
#  'half',
#  'halvah',
#  'hand',
#  'hard',
#  'hardly',
#  'hardness',
#  'harmonious',
#  'harmoniously',
#  'harmonize',
#  'harsh',
#  'hazelnut',
#  'heady',
#  'heart',
#  'heated',
#  'heather',
#  'heavily',
#  'heaviness',
#  'heavy',
#  'herb',
#  'herbaceous',
#  'herbal',
#  'herbs',
#  'herby',
#  'hibiscus',
#  'high',
#  'higher',
#  'highlighted',
#  'hill',
#  'hint',
#  'hints',
#  'hips',
#  'holcomb',
#  'home',
#  'honey',
#  'honeydew',
#  'honeyed',
#  'honeyish',
#  'honeysuckle',
#  'hop',
#  'hops',
#  'hot',
#  'humus',
#  'ice',
#  'identified',
#  'imagination',
#  'immediately',
#  'immense',
#  'immensely',
#  'impact',
#  'impeccably',
#  'impressed',
#  'impression',
#  'impressive',
#  'impressively',
#  'incense',
#  'inclined',
#  'including',
#  'inert',
#  'inflected',
#  'influence',
#  'influenced',
#  'infused',
#  'ingratiating',
#  'inside',
#  'instant',
#  'intact',
#  'integrated',
#  'intense',
#  'intensely',
#  'intensifies',
#  'intensify',
#  'intensifying',
#  'intensity',
#  'interesting',
#  'intricate',
#  'intricately',
#  'intrigue',
#  'intriguing',
#  'inviting',
#  'invitingly',
#  'jam',
#  'jasmine',
#  'jennifer',
#  'jim',
#  'john',
#  'jong',
#  'juicy',
#  'juniper',
#  'just',
#  'k500',
#  'kefir',
#  'ken',
#  'kenya',
#  'kenyas',
#  'keurig',
#  'kevin',
#  'key',
#  'kind',
#  'kiwi',
#  'knit',
#  'kohmescher',
#  'kona',
#  'kumquat',
#  'laced',
#  'lack',
#  'lacks',
#  'lactic',
#  'laden',
#  'lantana',
#  'lasting',
#  'lasts',
#  'latin',
#  'lavender',
#  'lavish',
#  'lavishly',
#  'layered',
#  'layers',
#  'lead',
#  'leading',
#  'leads',
#  'leaf',
#  'lean',
#  'leaning',
#  'leanish',
#  'leans',
#  'leather',
#  'leaves',
#  'leaving',
#  'led',
#  'left',
#  'lemon',
#  'lemongrass',
#  'lemony',
#  'levitating',
#  'levitatingly',
#  'licorice',
#  'lift',
#  'lifted',
#  'lifts',
#  'light',
#  'lighter',
#  'lightish',
#  'lightly',
#  'like',
#  'liked',
#  'lilac',
#  'lily',
#  'lime',
#  'limited',
#  'lindsey',
#  'linger',
#  'lingering',
#  'lingers',
#  'lingle',
#  'liqueur',
#  'little',
#  'lively',
#  'long',
#  'loquat',
#  'losing',
#  'loss',
#  'lost',
#  'lot',
#  'lots',
#  'lovely',
#  'low',
#  'lower',
#  'luscious',
#  'lush',
#  'lushly',
#  'luxuriously',
#  'lychee',
#  'lyric',
#  'lyrical',
#  'lyrically',
#  'macadamia',
#  'mace',
#  'machine',
#  'magnolia',
#  'main',
#  'maintain',
#  'maintaining',
#  'maintains',
#  'majority',
#  'make',
#  'makes',
#  'malic',
#  'malt',
#  'malty',
#  'mandarin',
#  'mango',
#  'maple',
#  'marjoram',
#  'marmalade',
#  'mars',
#  'marshmallow',
#  'massively',
#  'masters',
#  'matrix',
#  'matrixed',
#  'meadow',
#  'meadowy',
#  'mediterranean',
#  'medium',
#  'medley',
#  'mellow',
#  'melodic',
#  'melon',
#  'memory',
#  'menthol',
#  'mesquite',
#  'metallic',
#  'meyer',
#  'meza',
#  'mid',
#  'middle',
#  'miguel',
#  'mild',
#  'mildew',
#  'mildewed',
#  'mildly',
#  'milk',
#  'minority',
#  'mint',
#  'minty',
#  'mixed',
#  'ml',
#  'moderately',
#  'modulating',
#  'moist',
#  'molasses',
#  'monotoned',
#  'mouth',
#  'mouthfeel',
#  'moves',
#  'mulberry',
#  'multi',
#  'mushroom',
#  'musk',
#  'musky',
#  'mustard',
#  'mustiness',
#  'musty',
#  'muted',
#  'mutes',
#  'myrrh',
#  'narcissus',
#  'natural',
#  'naturally',
#  'near',
#  'nectar',
#  'nectarine',
#  'neill',
#  'nespresso',
#  'netting',
#  'neutral',
#  'new',
#  'newbom',
#  'newton',
#  'nib',
#  'nibs',
#  'nice',
#  'nicely',
#  'night',
#  'nominated',
#  'nominating',
#  'nose',
#  'note',
#  'noted',
#  'notes',
#  'nougat',
#  'nuance',
#  'nuanced',
#  'nuances',
#  'nut',
#  'nutella',
#  'nutmeg',
#  'nuts',
#  'nuttiness',
#  'nutty',
#  'oak',
#  'odd',
#  'oddly',
#  'offered',
#  'old',
#  'oolong',
#  'open',
#  'opens',
#  'opulence',
#  'opulent',
#  'opulently',
#  'orange',
#  'oranges',
#  'orangy',
#  'orchid',
#  'oregano',
#  'origin',
#  'original',
#  'ounce',
#  'ounces',
#  'overall',
#  'overripe',
#  'owen',
#  'owing',
#  'package',
#  'palate',
#  'panel',
#  'panelist',
#  'panelists',
#  'papaya',
#  'parsley',
#  'particular',
#  'particularly',
#  'parts',
#  'passion',
#  'passionfruit',
#  'past',
#  'paste',
#  'patience',
#  'patient',
#  'peach',
#  'pear',
#  'pecan',
#  'peel',
#  'penetrating',
#  'pepper',
#  'peppercorn',
#  'peppermint',
#  'peppery',
#  'perceptible',
#  'perfectly',
#  'performance',
#  'perfumy',
#  'perique',
#  'perry',
#  'persimmon',
#  'persist',
#  'persistence',
#  'persistent',
#  'persisting',
#  'persists',
#  'persuasively',
#  'pert',
#  'pervasive',
#  'petrichor',
#  'picked',
#  'pie',
#  'pine',
#  'pineapple',
#  'pink',
#  'pipe',
#  'pistachio',
#  'platinum',
#  'pleasant',
#  'pleasantly',
#  'pleasing',
#  'pleasingly',
#  'pleasure',
#  'plum',
#  'plumeria',
#  'plummy',
#  'plump',
#  'pluot',
#  'plus',
#  'plush',
#  'plushly',
#  'pod',
#  'points',
#  'poised',
#  'pomegranate',
#  'pomelo',
#  'port',
#  'positive',
#  'powder',
#  'power',
#  'powerful',
#  'powerfully',
#  'prairie',
#  'praise',
#  'praised',
#  'praline',
#  'pre',
#  'predictably',
#  'presence',
#  'present',
#  'presentation',
#  'preserves',
#  'pretty',
#  'prevail',
#  'prevails',
#  'probably',
#  'problem',
#  'processed',
#  'processing',
#  'produce',
#  'produced',
#  'professionals',
#  'profile',
#  'profoundly',
#  'prominent',
#  'promise',
#  'pronounced',
#  'proportions',
#  'provoked',
#  'prune',
#  'pruny',
#  'pumpkin',
#  'pungency',
#  'pungent',
#  'pungently',
#  'pure',
#  'qualities',
#  'quality',
#  'quickly',
#  'quiet',
#  'quietly',
#  'quiets',
#  'quite',
#  'raisin',
#  'raisins',
#  'raisiny',
#  'range',
#  'ranging',
#  'raspberry',
#  'rated',
#  'rating',
#  'raw',
#  'read',
#  'reader',
#  'readers',
#  'reading',
#  'reads',
#  'ready',
#  'recede',
#  'recedes',
#  'red',
#  'redolent',
#  'redwood',
#  'refined',
#  'refreshing',
#  ...]

# %%
#checking how many words there are
len(bagofwords_p1.get_feature_names())
# Out:
# 1369

# %%
# 1. Instantiate the model
p1_model = LinearRegression()

# 2. Fit the model
p1_model.fit(p1_remain_transform, y_remain)
# Out:
# LinearRegression()

# %%
# 3. Scoring the training model
print(f'The accuracy score for training data is: {p1_model.score(p1_remain_transform, y_remain)}')

# 3. Scoring the validation model
print(f'The accuracy score for validation data is: {p1_model.score(p1_val_transform, y_val)}')
# Out:
# The accuracy score for training data is: 0.9566986404116862
# The accuracy score for validation data is: -0.9420896316264786

# %% [markdown]
# `p2` Bag of Words

# %%
# 1. Instantiate 
bagofwords_p2 = CountVectorizer(stop_words=('english'), min_df=5)

# 2. Fit 
bagofwords_p2.fit(X_remain["p2"])

# 3. Transform
p2_remain_transform = bagofwords.transform(X_remain["p2"])
p2_val_transform = bagofwords.transform(X_val["p2"])
p2_test_transform = bagofwords.transform(X_test["p2"])

# %%
#the following looks at the 20 most popular words from paragraph 2

word_counts = pd.DataFrame(
    {"counts": p2_remain_transform.toarray().sum(axis=0)},
    index=bagofwords.get_feature_names()
).sort_values("counts", ascending=False)

word_counts.head(20).plot(kind="bar", figsize=(15, 5), legend=False)
plt.title("Top 20 most frequently occurring words")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
bagofwords_p2.get_feature_names()
# Out:
# /Users/katemondal/opt/anaconda3/envs/capstone/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00',
#  '000',
#  '0042',
#  '0066',
#  '007',
#  '011',
#  '0115',
#  '020',
#  '021',
#  '0245',
#  '0489',
#  '0626',
#  '0748',
#  '0758',
#  '0777',
#  '0800',
#  '0921',
#  '0983',
#  '0998',
#  '10',
#  '100',
#  '1024',
#  '11',
#  '1107',
#  '12',
#  '1217',
#  '1282',
#  '13',
#  '130',
#  '1300',
#  '14',
#  '1439',
#  '1465',
#  '15',
#  '150',
#  '16',
#  '16th',
#  '17',
#  '1707',
#  '1725',
#  '17th',
#  '18',
#  '1830',
#  '19',
#  '1919',
#  '1958',
#  '1963',
#  '1965',
#  '1971',
#  '1975',
#  '1980',
#  '1980s',
#  '1983',
#  '1986',
#  '1990',
#  '1993',
#  '1994',
#  '1995',
#  '1997',
#  '1998',
#  '1999',
#  '19th',
#  '1cafe',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '204',
#  '205',
#  '206',
#  '207',
#  '208',
#  '20th',
#  '21',
#  '213',
#  '2132',
#  '2154',
#  '22',
#  '221',
#  '2222',
#  '223',
#  '2264',
#  '227',
#  '2275',
#  '23',
#  '230',
#  '2339',
#  '238',
#  '24',
#  '248',
#  '25',
#  '250',
#  '2545',
#  '256',
#  '26',
#  '2605',
#  '262',
#  '265',
#  '2680',
#  '27',
#  '277',
#  '28',
#  '2824',
#  '285',
#  '287',
#  '288',
#  '29',
#  '293',
#  '295',
#  '2983',
#  '299',
#  '2nd',
#  '30',
#  '300',
#  '303',
#  '3042',
#  '305',
#  '309',
#  '31',
#  '310',
#  '312',
#  '322',
#  '323',
#  '3232',
#  '327',
#  '3338',
#  '334',
#  '3394',
#  '34',
#  '340',
#  '34318227',
#  '345',
#  '354',
#  '356',
#  '3599',
#  '360',
#  '362',
#  '3642',
#  '368',
#  '375',
#  '376',
#  '3771',
#  '383',
#  '384',
#  '388',
#  '39',
#  '394',
#  '398',
#  '40',
#  '400',
#  '406',
#  '408',
#  '415',
#  '416',
#  '421',
#  '422',
#  '423',
#  '424',
#  '4268',
#  '428',
#  '4313',
#  '433',
#  '438',
#  '443',
#  '444',
#  '448',
#  '45',
#  '4500',
#  '451',
#  '454',
#  '455',
#  '4627',
#  '465',
#  '466',
#  '4788',
#  '479',
#  '488',
#  '49',
#  '4900',
#  '49th',
#  '49thparallelroasters',
#  '4artszerodefectcoffees',
#  '50',
#  '500',
#  '503',
#  '5033',
#  '509',
#  '510',
#  '512',
#  '515',
#  '5181',
#  '52',
#  '5200',
#  '525',
#  '528',
#  '5282',
#  '5295',
#  '5300',
#  '5301',
#  '534',
#  '5363',
#  '540',
#  '541',
#  '545',
#  '55',
#  '550',
#  '551',
#  '553',
#  '562',
#  '565',
#  '571',
#  '579',
#  '586',
#  '5950',
#  '5984',
#  '60',
#  '600',
#  '601',
#  '603',
#  '605',
#  '608',
#  '6092',
#  '612',
#  '6130',
#  '619',
#  '6228',
#  '624',
#  '6278',
#  '6333',
#  '6377',
#  '641',
#  '648',
#  '6485',
#  '6491',
#  '65',
#  '6500',
#  '6505',
#  '651',
#  '652',
#  '653',
#  '66',
#  '663',
#  '664',
#  '675',
#  '6768',
#  '678',
#  '6820',
#  '697',
#  '70',
#  '700',
#  '7018',
#  '704',
#  '707',
#  '7083',
#  '709',
#  '71',
#  '713',
#  '718',
#  '719',
#  '7200',
#  '7282',
#  '730422',
#  '7318',
#  '7338',
#  '74110',
#  '74112',
#  '745',
#  '748',
#  '749876',
#  '75',
#  '7508',
#  '751',
#  '753',
#  '763',
#  '7667',
#  '7678',
#  '7685',
#  '7687',
#  '7726',
#  '773',
#  '777',
#  '7797',
#  '782',
#  '796',
#  '80',
#  '800',
#  '8022',
#  '8060',
#  '808',
#  '809',
#  '81',
#  '8134',
#  '815',
#  '829',
#  '834',
#  '835',
#  '836',
#  '84',
#  '8400',
#  '844',
#  '846',
#  '8482',
#  '85',
#  '850',
#  '8559',
#  '858',
#  '86',
#  '860',
#  '866',
#  '874',
#  '877',
#  '879',
#  '8790',
#  '88',
#  '8804',
#  '882',
#  '884',
#  '886',
#  '8867',
#  '888',
#  '89',
#  '8916',
#  '892',
#  '894',
#  '899',
#  '90',
#  '900',
#  '905',
#  '91',
#  '910',
#  '916',
#  '9164',
#  '918',
#  '919',
#  '92',
#  '922',
#  '924',
#  '928',
#  '93',
#  '9309',
#  '933',
#  '935',
#  '937',
#  '94',
#  '944',
#  '945',
#  '949',
#  '94freshcoffee',
#  '95',
#  '955',
#  '9621',
#  '968',
#  '9744',
#  '978',
#  '9786',
#  '99',
#  '994',
#  '995',
#  '9955',
#  '999',
#  'aa',
#  'ab',
#  'absence',
#  'acatenango',
#  'access',
#  'accessible',
#  'according',
#  'account',
#  'accounts',
#  'aceh',
#  'achieve',
#  'achieved',
#  'achimbal',
#  'acid',
#  'acidity',
#  'acids',
#  'acidy',
#  'acquired',
#  'acre',
#  'acronym',
#  'act',
#  'active',
#  'actual',
#  'adam',
#  'adaptors',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'additives',
#  'adds',
#  'adhere',
#  'adhering',
#  'adjacent',
#  'admired',
#  'advantage',
#  'affiliated',
#  'affordable',
#  'aficionado',
#  'africa',
#  'african',
#  'aftertaste',
#  'age',
#  'aged',
#  'agencies',
#  'agency',
#  'aging',
#  'agitate',
#  'ago',
#  'agreeable',
#  'agricultural',
#  'agriculture',
#  'agronomy',
#  'aguila',
#  'aid',
#  'aida',
#  'aimed',
#  'aiming',
#  'aims',
#  'air',
#  'aka',
#  'al',
#  'alabama',
#  'alaska',
#  'alberta',
#  'alberto',
#  'alfred',
#  'alive',
#  'allegro',
#  'allegrocoffee',
#  'alleviating',
#  'alliance',
#  'allocation',
#  'allowed',
#  'allowing',
#  'allows',
#  'alpen',
#  'alpes',
#  'altitude',
#  'altitudes',
#  'alto',
#  'aluminum',
#  'amaro',
#  'amavida',
#  'america',
#  'american',
#  'americas',
#  'amy',
#  'anaerobic',
#  'analysis',
#  'ancient',
#  'andes',
#  'andrew',
#  'andy',
#  'angeles',
#  'angelo',
#  'angle',
#  'annual',
#  'anny',
#  'antigua',
#  'antonio',
#  'apparent',
#  'apparently',
#  'appeal',
#  'appear',
#  'appears',
#  'applications',
#  'applied',
#  'applying',
#  'approach',
#  'approximately',
#  'april',
#  'arabia',
#  'arabica',
#  'arabicas',
#  'arc',
#  'area',
#  'areas',
#  'arguably',
#  'aricha',
#  'ariz',
#  'arizona',
#  'aroma',
#  'aromatic',
#  'aromatics',
#  'array',
#  'arrayed',
#  'art',
#  'artisan',
#  'artisanal',
#  'artisanally',
#  'artisans',
#  'artists',
#  'arts',
#  'arusha',
#  'asia',
#  'asnakech',
#  'asociación',
#  'aspects',
#  'assertive',
#  'assistance',
#  'associated',
#  'associates',
#  'association',
#  'associative',
#  'assuming',
#  'astringent',
#  'ateng',
#  'atitlan',
#  'atlanta',
#  'atlas',
#  'ato',
#  'atom',
#  'atomcoffee2019',
#  'atomic',
#  'atomicafe',
#  'attention',
#  'attracted',
#  'attracting',
#  'attractive',
#  'atypical',
#  'auction',
#  'auctioned',
#  'august',
#  'auromar',
#  'aurora',
#  'australia',
#  'australian',
#  'authentic',
#  'authorized',
#  'available',
#  'avenue',
#  'average',
#  'averages',
#  'awake',
#  'award',
#  'awarded',
#  'awards',
#  'awareness',
#  'azul',
#  'b40',
#  'b60',
#  'b70',
#  'baba',
#  'babajavacoffee',
#  'backbone',
#  'bacteria',
#  'bag',
#  'bagersh',
#  'bags',
#  'baked',
#  'bakery',
#  'balance',
#  'balanced',
#  'balances',
#  'bali',
#  'bank',
#  'banko',
#  'bar',
#  'barbara',
#  'bard',
#  'bardcoffee',
#  'barefoot',
#  'barefootcoffeeroasters',
#  'barichu',
#  'barista',
#  'barrel',
#  'barrington',
#  'barringtoncoffee',
#  'bars',
#  'baru',
#  'base',
#  'based',
#  'basin',
#  'batak',
#  'batch',
#  'batches',
#  'batdorf',
#  'batdorfcoffee',
#  'batian',
#  'batlle',
#  'bay',
#  'beach',
#  'bean',
#  'beaned',
#  'beanfruit',
#  'beans',
#  'beansmith',
#  'bearing',
#  'beautiful',
#  'bed',
#  'bedford',
#  'beds',
#  'beer',
#  'began',
#  'beginning',
#  'beitou',
#  'belies',
#  'believes',
#  'bellingham',
#  'belt',
#  'ben',
#  'benchmark',
#  'bend',
#  'beneficio',
#  'benefiting',
#  'benefits',
#  'berkeley',
#  'berry',
#  'best',
#  'better',
#  'beverage',
#  'beverages',
#  'beverly',
#  'big',
#  'bigcreekcoffeeroasters',
#  'bigislandcoffeeroasters',
#  'bigshoulderscoffee',
#  'billings',
#  'bird',
#  'birdrockcoffee',
#  'bit',
#  'bitter',
#  'bitterroot',
#  'bittersweet',
#  'black',
#  'blackcoffeeinblackjar',
#  'blanca',
#  'blend',
#  'blended',
#  'blends',
#  'blogspot',
#  'blue',
#  'bluebottlecoffee',
#  'bluekoff',
#  'board',
#  'boat',
#  'bob',
#  'bodied',
#  'body',
#  'bold',
#  'bolivia',
#  'boma',
#  'bonbons',
#  'boot',
#  'boquete',
#  'border',
#  'bordering',
#  'born',
#  'boston',
#  'botanical',
#  'bottle',
#  'bottled',
#  'bottles',
#  'boulder',
#  'bourbon',
#  'boutique',
#  'boxes',
#  'bozeman',
#  'branch',
#  'branchstreetcoffee',
#  'brand',
#  'branded',
#  'brandon',
#  'brands',
#  'brazil',
#  'brazilian',
#  'brazils',
#  'break',
#  'breakfast',
#  'breaking',
#  'brenes',
#  'brew',
#  'brewed',
#  'brewer',
#  'brewers',
#  'brewery',
#  'brewing',
#  'brewlife',
#  'brews',
#  'bright',
#  'brighter',
#  'brightly',
#  'brightness',
#  'bring',
#  'bringing',
#  'brings',
#  'broad',
#  'brodsky',
#  'broken',
#  'bronson',
#  'brooke',
#  'brooklyn',
#  'bros',
#  'brother',
#  'brothers',
#  'brought',
#  'brown',
#  'bucks',
#  'buckscountycoffee',
#  'buena',
#  'buenavista',
#  'bufcafe',
#  'building',
#  'built',
#  'bulk',
#  'bunn',
#  'buoyant',
#  'burned',
#  'burundi',
#  'business',
#  'businesses',
#  'button',
#  'buyer',
#  'buyers',
#  'buys',
#  'ca',
#  'cacao',
#  'caf',
#  'cafe',
#  'cafegrumpy',
#  'cafekreyol',
#  'cafes',
#  'cafetaster',
#  'cafevirtuoso',
#  'caffe',
#  'caffeine',
#  'caffeluxxe',
#  'caffepronto',
#  'caffevita',
#  'caffè',
#  'café',
#  'cafés',
#  'caleb',
#  'calgary',
#  'california',
#  'called',
#  'calls',
#  'came',
#  'campbell',
#  'campos',
#  'canada',
#  'canadian',
#  'candies',
#  'canned',
#  'cans',
#  'capital',
#  'capitol',
#  'capricorn',
#  'capricorncoffees',
#  'capsule',
#  'capsules',
#  'caramelizing',
#  'caramelly',
#  'caranavi',
#  'carbon',
#  'carbonfund',
#  'carbonic',
#  'care',
#  'careful',
#  'carefully',
#  'caribou',
#  'cariboucoffee',
#  'carlos',
#  'carlsbad',
#  'carlson',
#  'carmelite',
#  'carmen',
#  'carolina',
#  'carriage',
#  'carry',
#  'case',
#  'castillo',
#  'cat',
#  'category',
#  'catimor',
#  'catuai',
#  'catuaí',
#  'caturra',
#  'cauca',
#  'cause',
#  'causes',
#  'cc',
#  'celebes',
#  'celebrated',
#  'center',
#  'centered',
#  'centers',
#  'central',
#  'cents',
#  'centuries',
#  'century',
#  'cerrado',
#  'cerro',
#  'certainly',
#  'certification',
#  'certified',
#  'certifier',
#  'certifying',
#  'chaang',
#  'chacolatay',
#  'chacon',
#  'chain',
#  'chains',
#  'challenges',
#  'champion',
#  'championship',
#  'championships',
#  'chanchamayo',
#  'chang',
#  'change',
#  'character',
#  'characteristic',
#  'characteristics',
#  'charcoal',
#  'charges',
#  'charlotte',
#  'charred',
#  'chateau',
#  'chattanooga',
#  'chef',
#  'cherries',
#  'cherry',
#  'chia',
#  'chiapas',
#  'chicago',
#  'chih',
#  'children',
#  'china',
#  'chloride',
#  'chocolate',
#  'chocolatefishcoffee',
#  'chocolaty',
#  'choice',
#  'choices',
#  'chris',
#  'christy',
#  'chromatic',
#  'chromaticcoffee',
#  'chronically',
#  'chuan',
#  'citrus',
#  'city',
#  'civet',
#  'civil',
#  'claim',
#  'claims',
#  'clan',
#  'clarity',
#  'class',
#  'classic',
#  'classically',
#  'clean',
#  'cleaner',
#  'cleanly',
#  'clear',
#  'clientele',
#  'clients',
#  'climate',
#  'clinging',
#  'clock',
#  'close',
#  'closely',
#  'closer',
#  'closet',
#  'cloud',
#  'club',
#  'cn',
#  'co2',
#  'coalition',
#  'coast',
#  'coastal',
#  'coava',
#  'coavacoffee',
#  'cocoa',
#  'code',
#  'coded',
#  'coffea',
#  'coffearoasterie',
#  'coffee',
#  'coffeebydesign',
#  'coffeehouse',
#  'coffeehouses',
#  'coffeeling',
#  'coffeelingcafe',
#  'coffeemaria',
#  'coffeemasters',
#  'coffeepleasetw',
#  'coffees',
#  'coffeeworks',
#  'colbran',
#  'cold',
#  'collaboration',
#  'collaborators',
#  'collection',
#  'collective',
#  'collectively',
#  'colombia',
#  'colombian',
#  'colonial',
#  'colony',
#  'color',
#  'colorado',
#  'colorful',
#  'columbus',
#  'column',
#  'com',
#  'combination',
#  'combine',
#  'combined',
#  'combines',
#  'combining',
#  'come',
#  'comes',
#  'comfortable',
#  'coming',
#  'commercial',
#  'commercialize',
#  'commitment',
#  'committed',
#  'communities',
#  'community',
#  'compact',
#  'companies',
#  'company',
#  'comparison',
#  'compatible',
#  'compelling',
#  'compete',
#  'competition',
#  'competitions',
#  'complete',
#  'completely',
#  'complex',
#  'complexity',
#  'complicated',
#  'component',
#  'components',
#  'composed',
#  'composing',
#  'comprehensive',
#  'compressed',
#  'comprised',
#  'compromise',
#  'concentrate',
#  'concentrates',
#  'conditions',
#  'conducted',
#  'confused',
#  'confusing',
#  'confusion',
#  'congo',
#  'congos',
#  'connections',
#  'conscious',
#  'consciouscup',
#  'consciousness',
#  'considerable',
#  'considerably',
#  'considering',
#  'consistency',
#  'consistently',
#  'consisting',
#  'consists',
#  'consortium',
#  'consumers',
#  'contains',
#  'contemporary',
#  'contest',
#  'contested',
#  'continue',
#  'continues',
#  'contrasting',
#  'contrasts',
#  'contribute',
#  'control',
#  'controlled',
#  'controls',
#  'convenience',
#  ...]

# %%
len(bagofwords_p2.get_feature_names())
# Out:
# 3366

# %%
# 1. Instantiate the model
p2_model = LinearRegression()

# 2. Fit the model
p2_model.fit(p2_remain_transform, y_remain)
# Out:
# LinearRegression()

# %%
# 3. Scoring the training model
print(f'The accuracy score for training data is: {p2_model.score(p2_remain_transform, y_remain)}')

# 3. Scoring the validation model
print(f'The accuracy score for training data is: {p2_model.score(p2_val_transform, y_val)}')
# Out:
# The accuracy score for training data is: 0.9329839991832624
# The accuracy score for training data is: -6.067977935823131

# %%
# 1. Instantiate 
bagofwords_p3 = CountVectorizer(stop_words='english', min_df=5)

# 2. Fit 
bagofwords_p3.fit(X_remain["p3"])

# 3. Transform
p3_remain_transform = bagofwords.transform(X_remain["p3"])
p3_val_transform = bagofwords.transform(X_val["p3"])
p3_test_transform = bagofwords.transform(X_test["p3"])

# %%
#the following looks at the 20 most popular words from paragraph 3

word_counts = pd.DataFrame(
    {"counts": p3_remain_transform.toarray().sum(axis=0)},
    index=bagofwords.get_feature_names()
).sort_values("counts", ascending=False)

word_counts.head(20).plot(kind="bar", figsize=(15, 5), legend=False)
plt.title("Top 20 most frequently occurring words")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/katemondal/opt/anaconda3/envs/capstone/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
bagofwords_p3.get_feature_names()
# Out:
# /Users/katemondal/opt/anaconda3/envs/capstone/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['12',
#  '1999',
#  'able',
#  'absence',
#  'accessible',
#  'acid',
#  'acidity',
#  'acidy',
#  'add',
#  'addition',
#  'adeptly',
#  'admire',
#  'admired',
#  'admirers',
#  'adventurer',
#  'adventurers',
#  'afford',
#  'affordable',
#  'aficionado',
#  'aficionados',
#  'africa',
#  'african',
#  'africas',
#  'afternoon',
#  'afternoons',
#  'aged',
#  'aggressive',
#  'agreeable',
#  'ahead',
#  'akin',
#  'ales',
#  'alive',
#  'almond',
#  'alternative',
#  'amazing',
#  'ambiguous',
#  'america',
#  'american',
#  'americans',
#  'anaerobic',
#  'anaerobically',
#  'ancient',
#  'animate',
#  'animated',
#  'antigua',
#  'appeal',
#  'appealing',
#  'appealingly',
#  'apple',
#  'appreciate',
#  'approachable',
#  'apricot',
#  'arabica',
#  'aroma',
#  'aromas',
#  'aromatic',
#  'aromatically',
#  'aromatics',
#  'array',
#  'art',
#  'aside',
#  'assertion',
#  'assertive',
#  'assertively',
#  'associate',
#  'associated',
#  'astringency',
#  'attention',
#  'attractive',
#  'attractively',
#  'austere',
#  'austerely',
#  'authoritative',
#  'authority',
#  'avoid',
#  'avoiders',
#  'backgrounded',
#  'bad',
#  'bag',
#  'baking',
#  'balance',
#  'balanced',
#  'balances',
#  'ballast',
#  'bargain',
#  'barrel',
#  'base',
#  'based',
#  'bean',
#  'beaned',
#  'beans',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'beer',
#  'berries',
#  'berry',
#  'berryish',
#  'best',
#  'better',
#  'beverage',
#  'beverages',
#  'big',
#  'bit',
#  'bite',
#  'bitter',
#  'bitterish',
#  'bitterness',
#  'bittersweet',
#  'bittersweetness',
#  'black',
#  'blend',
#  'blends',
#  'bloom',
#  'blossom',
#  'blue',
#  'blueberry',
#  'bodied',
#  'body',
#  'bold',
#  'bomb',
#  'bonus',
#  'bourbon',
#  'bracing',
#  'bracingly',
#  'brandy',
#  'brazil',
#  'breakfast',
#  'breakfasts',
#  'brew',
#  'brewed',
#  'brewing',
#  'bright',
#  'brighter',
#  'brightly',
#  'brightness',
#  'bring',
#  'brings',
#  'brisk',
#  'briskly',
#  'briskness',
#  'brought',
#  'budget',
#  'burned',
#  'burundi',
#  'butter',
#  'butterscotch',
#  'buttery',
#  'buy',
#  'cacao',
#  'caffeine',
#  'candidate',
#  'candy',
#  'canned',
#  'cappuccino',
#  'capsule',
#  'caramel',
#  'caramelly',
#  'carbon',
#  'care',
#  'caribbean',
#  'carried',
#  'carries',
#  'carry',
#  'case',
#  'cause',
#  'cedar',
#  'cedary',
#  'celebrated',
#  'center',
#  'centered',
#  'central',
#  'certain',
#  'certainly',
#  'certified',
#  'chair',
#  'challenging',
#  'character',
#  'characteristic',
#  'characteristically',
#  'characterize',
#  'characterized',
#  'cheap',
#  'cheese',
#  'cherry',
#  'chocolate',
#  'chocolaty',
#  'choice',
#  'cigar',
#  'cigars',
#  'cinnamon',
#  'citrus',
#  'citrusy',
#  'clarity',
#  'classic',
#  'classically',
#  'classicists',
#  'clean',
#  'cleanly',
#  'clear',
#  'close',
#  'clove',
#  'coast',
#  'cocoa',
#  'coconut',
#  'coffee',
#  'coffees',
#  'cold',
#  'colombia',
#  'combination',
#  'combine',
#  'combined',
#  'combining',
#  'come',
#  'comes',
#  'comfort',
#  'comfortable',
#  'company',
#  'compatible',
#  'compelling',
#  'complement',
#  'complete',
#  'completely',
#  'completeness',
#  'complex',
#  'complexity',
#  'complexly',
#  'complicated',
#  'complicates',
#  'complicating',
#  'complication',
#  'complications',
#  'components',
#  'composed',
#  'concentrated',
#  'confident',
#  'confidently',
#  'congo',
#  'considerable',
#  'considerably',
#  'consistent',
#  'context',
#  'contradiction',
#  'contrast',
#  'contributes',
#  'convenience',
#  'corner',
#  'costa',
#  'crave',
#  'creamy',
#  'credentials',
#  'crisp',
#  'crisply',
#  'crop',
#  'culinary',
#  'cup',
#  'cuppers',
#  'cupping',
#  'cups',
#  'curious',
#  'currant',
#  'cut',
#  'dairy',
#  'dark',
#  'darker',
#  'darkish',
#  'day',
#  'decaf',
#  'decaffeinated',
#  'decaffeination',
#  'decent',
#  'deep',
#  'deepened',
#  'deepens',
#  'deeper',
#  'deeply',
#  'definitely',
#  'deftly',
#  'delicacy',
#  'delicate',
#  'delicately',
#  'delicious',
#  'demitasse',
#  'depth',
#  'derived',
#  'designed',
#  'despite',
#  'dessert',
#  'desserts',
#  'develop',
#  'developed',
#  'develops',
#  'difference',
#  'different',
#  'difficult',
#  'dimension',
#  'dinner',
#  'discreet',
#  'discreetly',
#  'display',
#  'displayed',
#  'displaying',
#  'displays',
#  'distinct',
#  'distinction',
#  'distinctive',
#  'distinctively',
#  'distinguished',
#  'distracting',
#  'does',
#  'doesn',
#  'dominate',
#  'dominated',
#  'dominican',
#  'don',
#  'doubtless',
#  'dr',
#  'drama',
#  'dramatic',
#  'dried',
#  'drier',
#  'drink',
#  'drinker',
#  'drinkers',
#  'drinking',
#  'drinks',
#  'drip',
#  'driven',
#  'dry',
#  'drying',
#  'dynamic',
#  'earth',
#  'earthiness',
#  'earthy',
#  'east',
#  'easy',
#  'easygoing',
#  'economic',
#  'ecuador',
#  'edge',
#  'edged',
#  'el',
#  'elegance',
#  'elegant',
#  'elegantly',
#  'elements',
#  'emerging',
#  'emphasizes',
#  'encourages',
#  'end',
#  'energetic',
#  'engaging',
#  'engagingly',
#  'enigmatic',
#  'enjoy',
#  'enjoys',
#  'entertaining',
#  'enthusiasts',
#  'enticing',
#  'entirely',
#  'enveloped',
#  'enveloping',
#  'environmental',
#  'environmentally',
#  'equal',
#  'equally',
#  'esmeralda',
#  'especially',
#  'espresso',
#  'espressos',
#  'essentially',
#  'estate',
#  'ethiopia',
#  'ethiopian',
#  'evocative',
#  'evokes',
#  'example',
#  'excellent',
#  'exceptional',
#  'exceptionally',
#  'excite',
#  'excitement',
#  'exciting',
#  'exhilarating',
#  'exhilaratingly',
#  'exotic',
#  'exotically',
#  'expensive',
#  'experience',
#  'experiences',
#  'experimental',
#  'experimentally',
#  'expressed',
#  'expresses',
#  'expression',
#  'expressive',
#  'exquisitely',
#  'extraordinarily',
#  'extraordinary',
#  'extravagant',
#  'extravagantly',
#  'extreme',
#  'extremely',
#  'exuberant',
#  'factor',
#  'fair',
#  'familiar',
#  'famous',
#  'fans',
#  'far',
#  'farm',
#  'farmers',
#  'fascinating',
#  'fashioned',
#  'fault',
#  'favor',
#  'favorite',
#  'feel',
#  'felt',
#  'ferment',
#  'fermentation',
#  'fermented',
#  'fermenty',
#  'fig',
#  'fine',
#  'finely',
#  'finesse',
#  'finest',
#  'finish',
#  'finishing',
#  'fir',
#  'fireworks',
#  'flat',
#  'flavor',
#  'flavored',
#  'flavors',
#  'flawless',
#  'floral',
#  'florals',
#  'flower',
#  'flowers',
#  'folks',
#  'food',
#  'footed',
#  'forceful',
#  'forest',
#  'format',
#  'forward',
#  'fragrant',
#  'fragrantly',
#  'framed',
#  'free',
#  'french',
#  'fresh',
#  'freshness',
#  'friendly',
#  'fruit',
#  'fruits',
#  'fruity',
#  'fudge',
#  'fudgy',
#  'fully',
#  'garden',
#  'geisha',
#  'genius',
#  'gentle',
#  'gently',
#  'genuinely',
#  'gesha',
#  'gift',
#  'given',
#  'gives',
#  'giving',
#  'going',
#  'good',
#  'gorgeous',
#  'grace',
#  'graceful',
#  'gracefully',
#  'grand',
#  'grandly',
#  'grapefruit',
#  'grapefruity',
#  'grappa',
#  'great',
#  'green',
#  'grounded',
#  'growing',
#  'grown',
#  'guatemala',
#  'guinea',
#  'guineas',
#  'guji',
#  'haiti',
#  'half',
#  'handle',
#  'happy',
#  'hard',
#  'harmonious',
#  'harmoniously',
#  'harmony',
#  'hawai',
#  'hawaii',
#  'hawaiian',
#  'hazelnut',
#  'heady',
#  'heart',
#  'hearty',
#  'heavy',
#  'hedonists',
#  'help',
#  'herb',
#  'herbaceous',
#  'herbal',
#  'herbs',
#  'high',
#  'higher',
#  'highlights',
#  'highly',
#  'hint',
#  'hints',
#  'hits',
#  'holiday',
#  'holidays',
#  'honduras',
#  'honey',
#  'honeyish',
#  'honeysuckle',
#  'hot',
#  'house',
#  'hulled',
#  'iced',
#  'ideal',
#  'idealists',
#  'idiosyncratic',
#  'imagine',
#  'impact',
#  'impeccable',
#  'impression',
#  'impressive',
#  'impressively',
#  'impulses',
#  'incense',
#  'indonesia',
#  'inflected',
#  'influenced',
#  'ingratiating',
#  'inherent',
#  'instant',
#  'integrated',
#  'intense',
#  'intensely',
#  'intensity',
#  'intentionally',
#  'interested',
#  'interesting',
#  'intimations',
#  'intricacy',
#  'intricate',
#  'intricately',
#  'intrigue',
#  'intriguing',
#  'intriguingly',
#  'introduction',
#  'invigorating',
#  'inviting',
#  'invitingly',
#  'invokes',
#  'island',
#  'italian',
#  'jasmine',
#  'java',
#  'juicy',
#  'just',
#  'juxtaposed',
#  'juxtaposition',
#  'ka',
#  'ken',
#  'kenya',
#  'kenyas',
#  'keurig',
#  'key',
#  'kind',
#  'know',
#  'known',
#  'kona',
#  'lactic',
#  'laden',
#  'large',
#  'latin',
#  'latte',
#  'lavender',
#  'lavish',
#  'lavishly',
#  'layered',
#  'layering',
#  'layers',
#  'leading',
#  'leads',
#  'lean',
#  'leaning',
#  'leather',
#  'lemon',
#  'lemony',
#  'levity',
#  'life',
#  'lift',
#  'light',
#  'lighter',
#  'lightly',
#  'like',
#  'limited',
#  'line',
#  'little',
#  'lively',
#  'local',
#  'lone',
#  'long',
#  'look',
#  'looking',
#  'lot',
#  'lots',
#  'love',
#  'lovely',
#  'lover',
#  'lovers',
#  'loving',
#  'low',
#  'lush',
#  'lushly',
#  'lyric',
#  'lyrical',
#  'lyrically',
#  'maintain',
#  'maintains',
#  'make',
#  'makes',
#  'making',
#  'malt',
#  'malty',
#  'manages',
#  'mango',
#  'maracaturra',
#  'maragogipe',
#  'maragogype',
#  'maybe',
#  'meadowy',
#  'medium',
#  'method',
#  'mexico',
#  'mild',
#  'mildly',
#  'milk',
#  'mocha',
#  'mode',
#  'moderate',
#  'moderately',
#  'moist',
#  'molasses',
#  'morning',
#  'mornings',
#  'mountain',
#  'mouthfeel',
#  'multi',
#  'multilayered',
#  'muscular',
#  'musk',
#  'musky',
#  'mustiness',
#  'musty',
#  'muted',
#  'named',
#  'narcissus',
#  'natural',
#  'naturally',
#  'nectar',
#  'need',
#  'nespresso',
#  'nets',
#  'netting',
#  'new',
#  'newer',
#  'nib',
#  'nicaragua',
#  'nice',
#  'nicely',
#  'non',
#  'north',
#  'note',
#  'notes',
#  'nuance',
#  'nuanced',
#  'nut',
#  'nuts',
#  'nutty',
#  'oak',
#  'oaky',
#  'odd',
#  'offering',
#  'offers',
#  'old',
#  'opportunity',
#  'opulent',
#  'orange',
#  'organic',
#  'organically',
#  'origin',
#  'original',
#  'originality',
#  'origins',
#  'ounces',
#  'outstanding',
#  'overbearing',
#  'owing',
#  'owners',
#  'pacamara',
#  'package',
#  'palate',
#  'palates',
#  'panama',
#  'papua',
#  'paradise',
#  'paradox',
#  'paradoxically',
#  'particular',
#  'particularly',
#  'parts',
#  'patience',
#  'patient',
#  'peaberry',
#  'peach',
#  'peet',
#  'people',
#  'perfect',
#  'perfectly',
#  'perfumed',
#  'perfumy',
#  'persuasive',
#  'peru',
#  'pink',
#  'pipe',
#  'pistachio',
#  'pleasant',
#  'pleasantly',
#  'pleasing',
#  'pleasingly',
#  'pleasure',
#  'pleasures',
#  'plump',
#  'plus',
#  'plush',
#  'png',
#  'pod',
#  'point',
#  'pointu',
#  'poised',
#  'port',
#  'possibly',
#  'potential',
#  'power',
#  'powerful',
#  'powerfully',
#  'pre',
#  'prefer',
#  'prepared',
#  'presence',
#  'presentation',
#  'preserve',
#  'preserves',
#  'press',
#  'pretty',
#  'price',
#  'priced',
#  'probably',
#  'process',
#  'processed',
#  'processing',
#  'produce',
#  'produced',
#  'producer',
#  'produces',
#  'production',
#  'profile',
#  'profiles',
#  'prominent',
#  'pronounced',
#  'pungency',
#  'pungent',
#  'pungently',
#  'pure',
#  'purist',
#  'purists',
#  'purity',
#  'pursuit',
#  'quality',
#  'quantities',
#  'quiet',
#  'quietly',
#  'quite',
#  'raisiny',
#  'range',
#  'ranging',
#  'rare',
#  'raspberry',
#  'rated',
#  'read',
#  'reassuring',
#  'red',
#  'redolent',
#  'refined',
#  'refreshing',
#  'refreshingly',
#  'regarded',
#  'region',
#  'relatively',
#  'remarkable',
#  'reminiscent',
#  'rendition',
#  'republic',
#  'resonance',
#  'resonant',
#  'resonantly',
#  'respects',
#  'restrained',
#  'retains',
#  'rewards',
#  'rica',
#  'rich',
#  'richly',
#  'richness',
#  'rieslings',
#  'right',
#  'ringing',
#  'ripe',
#  'roast',
#  'roasted',
#  'roaster',
#  'roasters',
#  'roastiness',
#  'roasting',
#  'roasts',
#  'roasty',
#  'robust',
#  'robusta',
#  'romantic',
#  'romantics',
#  'root',
#  'rose',
#  'rough',
#  'round',
#  'rounded',
#  'rounder',
#  'rounding',
#  'roundly',
#  'rounds',
#  'rugged',
#  'rum',
#  'running',
#  'rustic',
#  'rwanda',
#  'salty',
#  'salvador',
#  'sample',
#  'sampling',
#  'sandalwood',
#  'satisfy',
#  'satisfying',
#  'satisfyingly',
#  'saturated',
#  'savory',
#  'say',
#  'says',
#  'scaled',
#  'school',
#  'seattle',
#  'seductive',
#  'seeking',
#  'seller',
#  'sensation',
#  'sensations',
#  'sensitive',
#  'sensory',
#  'set',
#  'setting',
#  'sharp',
#  'sharpness',
#  'shifting',
#  'shimmer',
#  'shoppers',
#  'short',
#  'shot',
#  'shots',
#  'showy',
#  'sidamo',
#  'sidra',
#  'silky',
#  'similar',
#  'simple',
#  'simplicity',
#  'simply',
#  'simultaneously',
#  'single',
#  'singular',
#  'sip',
#  'sitting',
#  'sized',
#  'skillfully',
#  'sl28',
#  'slight',
#  'slightly',
#  'slow',
#  'small',
#  'smoke',
#  'smoky',
#  'smooth',
#  'smoothly',
#  'soaring',
#  'social',
#  'socially',
#  'socio',
#  'soft',
#  'softened',
#  'softly',
#  'solid',
#  'somewhat',
#  'sophisticated',
#  'sort',
#  'sounds',
#  'southern',
#  'specialty',
#  'spectacular',
#  'spectrum',
#  'spice',
#  'spices',
#  'spicy',
#  'spirits',
#  'splash',
#  'splendid',
#  'splendidly',
#  'spring',
#  'stand',
#  'starbucks',
#  'startling',
#  'startlingly',
#  'stated',
#  'steroids',
#  'stone',
#  'stonefruit',
#  'store',
#  'story',
#  'straight',
#  'straightforward',
#  'strawberry',
#  'striking',
#  'strikingly',
#  'strong',
#  'structure',
#  'structured',
#  'sturdy',
#  'style',
#  'styles',
#  'suave',
#  'suavely',
#  'subdued',
#  'substance',
#  'substantial',
#  'subtle',
#  'subtlety',
#  'subtly',
#  'sugar',
#  'suggest',
#  'suggesting',
#  'suggestion',
#  'suggestions',
#  'suggests',
#  'sulawesi',
#  'sumatra',
#  'sumatras',
#  'summer',
#  'summery',
#  'superb',
#  'superbly',
#  'supermarket',
#  'support',
#  'supported',
#  'supporting',
#  'supports',
#  'sure',
#  'surprise',
#  'surprising',
#  'sweet',
#  'sweetener',
#  'sweeter',
#  'sweetly',
#  'sweetness',
#  'syrupy',
#  'table',
#  'tactful',
#  'tactfully',
#  'taiwan',
#  ...]

# %%
len(bagofwords_p3.get_feature_names())
# Out:
# 1127

# %%
# 1. Instantiate the model
lr_model = LinearRegression()

# 2. Fit the model
lr_model.fit(p3_remain_transform, y_remain)
# Out:
# LinearRegression()

# %%
# 3. Scoring the model
print(f'The accuracy score for training data is: {lr_model.score(p3_remain_transform, y_remain)}')
# Out:
# The accuracy score for training data is: 0.9369032006927026

# %%
# 3. Scoring the model
print(f'The accuracy score for validation data is: {lr_model.score(p3_val_transform, y_val)}')
# Out:
# The accuracy score for validation data is: -1.6201428454126954
